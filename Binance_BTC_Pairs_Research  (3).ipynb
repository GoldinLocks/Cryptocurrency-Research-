# %% [markdown]
# ### CRYPTO MEAN REVERSION PAIRS TRADING WITH INCLUSION OF A KALMAN FILTER

# %% [markdown]
# In this notebook we are going look at the concept of building a trading strategy backtest based on mean reverting, co-integrated pairs of crypto currencies. So to restate the theory in in terms of US equities, stocks that are statistically co-integrated move in a way that means when their prices start to diverge by a certain amount (i.e. the spread between the 2 stocks prices increases), we would expect that divergence to
# eventually revert back to the mean. In this instance we would look to sell the outperforming stock,and buy the under performing stock in our expectance that the under performing stock would eventually “catch up” with the overpeforming stock and rise in price, or vice versa the overperforming stock would in time suffer from the same downward pressure of the underperforming stock and fall in relative value.
#
# Hence, pairs trading is a market neutral trading strategy enabling traders to profit from virtually any market conditions: Bull Market, Bear Market, or Sideways Market.
#
# So in our search for co-integrated Altcoins, economic theory would suggest that we are more likley to find pairs of that are driven by the same factors, if we search for pairs that are drawn from similar/the same blockchain & technology. After all, it is logical to expect
# 2 Altcoins with similar blockchain tech and use case could be considered similar products, to be at the mercy of the same general ups and downs of the volatile crypto market.

# %% [markdown]
# ### Kalman Filter

# %% [markdown]
# So what is a Kalman Filter? Well this site (http://www.bzarg.com/p/how-a-kalman-filter-works-in-pictures/) explains and states the following:
#
# You can use a Kalman filter in any place where you have uncertain information about some dynamic system, and you can make an educated guess about what the system is going to do next. Even if messy reality comes along and interferes with the clean motion you guessed about, the Kalman filter will often do a very good job of figuring out what actually happened. And it can take advantage of correlations between crazy phenomena that you maybe wouldn’t have thought to exploit!
#
# Kalman filters are ideal for systems which are continuously changing. They have the advantage that they are light on memory (they don’t need to keep any history other than the previous state), and they are very fast, making them well suited for real time problems and embedded systems.
#
# So lets start to import the relevant modules we will need for our strategy backtest:

# %%
from time import time
import numpy as np                  
import matplotlib.pyplot as plt   
import datetime as dt  
import pandas as pd
import math
import os.path
import time
import json
import requests
from bitmex import bitmex
from binance.client import Client
from datetime import timedelta, datetime
from dateutil import parser
from tqdm import tqdm_notebook 
import seaborn as sns
import matplotlib as mpl
mpl.style.use('seaborn')
import statsmodels.api as sm
from pykalman import KalmanFilter
from math import sqrt
import warnings
warnings.filterwarnings('ignore')
import ffn

# %%
### CONSTANTS
binsizes = {"1m": 1, "5m": 5, "1h": 60, "1d": 1440}
batch_size = 750
binance_client = Client(api_key=binance_api_key, api_secret=binance_api_secret)

# %%
### FUNCTIONS
def minutes_of_new_data(symbol, kline_size, data, source):
    if len(data) > 0:  old = parser.parse(data["timestamp"].iloc[-1])
    elif source == "binance": old = datetime.strptime('30 Nov 2017', '%d %b %Y')
    if source == "binance": new = pd.to_datetime(binance_client.get_klines(symbol=symbol, interval=kline_size)[-1][0], unit='ms')
    return old, new

## Get Historical Pricing from Binance 
def get_all_binance(symbol, kline_size, save = False):
    filename = 'Binance_%s_%s_data.csv' % (symbol, kline_size)
    if os.path.isfile(filename): data_df = pd.read_csv(filename)
    else: data_df = pd.DataFrame()
    oldest_point, newest_point = minutes_of_new_data(symbol, kline_size, data_df, source = "binance")
    delta_min = (newest_point - oldest_point).total_seconds()/60
    available_data = math.ceil(delta_min/binsizes[kline_size])
    if oldest_point == datetime.strptime('30 Nov 2017', '%d %b %Y'): print('Downloading all available %s data for %s. Be patient..!' % (kline_size, symbol))
    else: print('Downloading %d minutes of new data available for %s, i.e. %d instances of %s data.' % (delta_min, symbol, available_data, kline_size))
    klines = binance_client.get_historical_klines(symbol, kline_size, oldest_point.strftime("%d %b %Y %H:%M:%S"), newest_point.strftime("%d %b %Y %H:%M:%S"))
    data = pd.DataFrame(klines, columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av', 'ignore' ])
    data = data.drop('ignore', axis=1)
    data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')
    if len(data_df) > 0:
        temp_df = pd.DataFrame(data)
        data_df = data_df.append(temp_df)
    else: data_df = data
    data_df.set_index('timestamp', inplace=True)
    print('All caught up..!')
    return data_df

# %%
# For all Binance USDT symbols
# https://steemit.com/money/@marketstack/visualizing-alt-coin-correlation
symbols = json.loads(requests.get("https://api.binance.com/api/v1/exchangeInfo").text)
symbols = [symbol['symbol'] for symbol in symbols['symbols'] if symbol['quoteAsset'] == 'BTC']

# %% [markdown]
# What we're left with here is a list of any pair with BTC as the quote side of the pair. We will combine this data with the price history of BTC/USDT to create time series for each cryptocurrency quoted in USDT instead of BTC.
#
# To do this we'll use our get_bars function to retrieve the data for BTC/USDT

# %%
btcusdt = get_all_binance('BTCUSDT', '1d', save = False)
# Out:
# Downloading all available 1d data for BTCUSDT. Be patient..!
# All caught up..!

# %%
# Downloading all Altcoin price data
price_data = []
new_symbols = []
binance_symbols = symbols
for symbol in binance_symbols:
    data = get_all_binance(symbol, '1d', save = False)
    new_symbols.append(symbol.replace('BTC','USDT')) 
    price_data.append(data['close'].astype('float') * btcusdt['close'].astype('float'))
# Out:
# Downloading all available 1d data for ETHBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LTCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BNBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NEOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GASBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for HSRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MCOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WTCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LRCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for QTUMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for YOYOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for OMGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ZRXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for STRATBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SNGLSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BQXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for KNCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for FUNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SNMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for IOTABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LINKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XVGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SALTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MDABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MTLBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SUBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for EOSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SNTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ETCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MTHBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ENGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DNTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ZECBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BNTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ASTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DASHBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for OAXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ICNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BTGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for EVXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for REQBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for VIBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TRXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for POWRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ARKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XRPBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MODBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ENJBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for STORJBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for VENBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for KMDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RCNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NULSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RDNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XMRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DLTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for AMBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BATBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCPTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ARNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GVTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CDTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GXSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for POEBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for QSPBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BTSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XZCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LSKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TNTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for FUELBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MANABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DGDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ADXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ADABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PPTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CMTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XLMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CNDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LENDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WABIBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TNBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WAVESBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GTOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ICXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for OSTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ELFBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for AIONBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NEBLBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BRDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for EDOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WINGSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NAVBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LUNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TRIGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for APPCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for VIBEBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RLCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for INSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PIVXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for IOSTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CHATBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for STEEMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NANOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for VIABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BLZBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for AEBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RPXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NCASHBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for POABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ZILBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ONTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for STORMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XEMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WANBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WPRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for QLCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SYSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GRSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CLOAKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GNTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for LOOMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for REPBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TUSDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ZENBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SKYBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CVCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for THETABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for IOTXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for QKCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for AGIBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NXSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DATABTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for SCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NPXSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for KEYBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for NASBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MFTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DENTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ARDRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for HOTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for VETBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DOCKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for POLYBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PHXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for HCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for GOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PAXBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RVNBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DCRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MITHBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCHABCBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BCHSVBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for RENBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BTTBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ONGBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for FETBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CELRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for MATICBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ATOMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PHBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TFUELBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ONEBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for FTMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BTCBBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ALGOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ERDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DOGEBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for DUSKBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for ANKRBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for WINBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for COSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for COCOSBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for TOMOBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for PERLBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for CHZBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BANDBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for BEAMBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for XTZBTC. Be patient..!
# All caught up..!
# Downloading all available 1d data for HBARBTC. Be patient..!
# All caught up..!

# %%
# Merge all price data into a single dataframe and drop all NaNs
combo = pd.concat(price_data, axis = 1)
combo.columns = binance_symbols
combo = combo.dropna(axis=1, how='any', thresh=None, subset=None, inplace=False)
combo.head()
# Out:
#                 ETHBTC      LTCBTC    BNBBTC     NEOBTC     GASBTC     MCOBTC  \
# timestamp
# 2017-11-30  429.480443   85.412012  1.967792  32.557119  18.595634   5.696758
# 2017-12-01  457.166427   97.090042  2.053728  35.583867  19.075109   6.232568
# 2017-12-02  457.140840   98.805061  2.068013  34.967822  18.883277   6.120186
# 2017-12-03  459.356133   99.718277  2.288909  36.566718  19.293828   6.688081
# 2017-12-04  465.255799  103.226785  2.541590  41.869664  21.861152  12.748479
#
#               WTCBTC    LRCBTC    QTUMBTC   YOYOBTC    ...       BTSBTC  \
# timestamp                                              ...
# 2017-11-30  6.670421  0.203273  11.875625  0.087567    ...     0.131645
# 2017-12-01  8.275298  0.232481  12.680796  0.128749    ...     0.145463
# 2017-12-02  9.637659  0.255697  12.501731  0.132314    ...     0.136670
# 2017-12-03  9.289844  0.284495  12.706237  0.124048    ...     0.143922
# 2017-12-04  9.147410  0.316454  13.420061  0.224169    ...     0.175538
#
#                XZCBTC    LSKBTC    TNTBTC   FUELBTC   MANABTC     BCDBTC  \
# timestamp
# 2017-11-30  35.420256  7.408737  0.073202  0.038470  0.015152  50.611610
# 2017-12-01  37.621852  7.715229  0.077853  0.044642  0.016067  56.006850
# 2017-12-02  37.526974  7.752598  0.076339  0.047916  0.017206  51.008807
# 2017-12-03  37.314800  7.764426  0.078604  0.047565  0.017083  50.021037
# 2017-12-04  39.889655  8.808145  0.083716  0.044811  0.018758  47.485479
#
#                 DGDBTC    ADXBTC    ADABTC
# timestamp
# 2017-11-30   98.556862  1.082384  0.118461
# 2017-12-01  105.188067  1.185590  0.131552
# 2017-12-02  100.438562  1.166102  0.132096
# 2017-12-03  108.762259  1.270847  0.131863
# 2017-12-04  119.831071  1.534218  0.136516
#
# [5 rows x 69 columns]

# %% [markdown]
# Plot the resulting DataFrame of price data just to make sure we have what we need and as a quick sanity check:

# %%
num_coins = len(combo.columns)
print('Number of Altcoins =', num_coins)
# Out:
# Number of Altcoins = 69

# %%
combo.div(combo.iloc[0,:]).plot(figsize=(12, 6))# Normalize Prices 
plt.title('ALL Binance USDT Denominated Altcoins Normalized Price Series')
plt.xlabel('Date')
plt.ylabel('Price ($USDT)')
plt.grid(b=None, which=u'major', axis=u'both')
plt.legend(bbox_to_anchor=(1.01, 1.1), loc='upper left', ncol=1)
plt.show();

# %% [markdown]
# Ok so it looks from the chart as if we have around price data downloaded for 69 Altcoins; this should be more than enough to find at least a couple of co-integrated pairs to run our backtest over.
#
# We will now define a quick function that will run our Altcoins, combining them into pairs one by one and running co-integration tests on each pair. That result will then be stored in a matrix that we initialise,
# and then we will be able to plot that matrix as a heatmap. Also, if the co-integration test meets our threshold statistical significance (in our case 5%), then that pair of Altcoin tickers will be stored in a list for later retrieval.

# %%
# Source: https://pythonforfinance.net/2018/07/04/mean-reversion-pairs-trading-with-inclusion-of-a-kalman-filter/
# NOTE CRITICAL LEVEL HAS BEEN SET TO 5% FOR COINTEGRATION TEST
def find_cointegrated_pairs(dataframe, critial_level = 0.05):
    n = dataframe.shape[1] # the length of dateframe
    pvalue_matrix = np.ones((n, n)) # initialize the matrix of p
    keys = dataframe.columns # get the column names
    pairs = [] # initilize the list for cointegration
    for i in range(n):
        for j in range(i+1, n): # for j bigger than i
            stock1 = dataframe[keys[i]] # obtain the price of "stock1"
            stock2 = dataframe[keys[j]]# obtain the price of "stock2"
            result = sm.tsa.stattools.coint(stock1, stock2) # get conintegration
            pvalue = result[1] # get the pvalue
            pvalue_matrix[i, j] = pvalue
            if pvalue < critial_level: # if p-value less than the critical level
                pairs.append((keys[i], keys[j], pvalue)) # record the contract with that p-value
    return pvalue_matrix, pairs

# %% [markdown]
# Let’s now run our data through our function, save the results and plot the heatmap:

# %%
df = combo

binance_symbols = df.columns

# Set up the split point for our "training data" on which to perform the co-integration test (the remaining dat awill be fed to our backtest function)
split = int(len(df) * 0.4)

# Run our dataframe (up to the split point) of ticker price data through our co-integration function and store results
pvalue_matrix,pairs = find_cointegrated_pairs(df[:split])

# Convert our matrix of stored results into a DataFrame
pvalue_matrix_df = pd.DataFrame(pvalue_matrix)

# Use Seaborn to plot a heatmap of our results matrix
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(pvalue_matrix_df,xticklabels=binance_symbols,yticklabels=binance_symbols,ax=ax,cmap="RdYlGn")
plt.title('Binance Altcoin P-value Matrix')
plt.show();

# %% [markdown]
# So we can see from the very dark red squares that it looks as though there are indeed a few pairs of Altcoins who’s co-integration score is below the 5% threshold
# hardcoded into the function we defined. To see more explicitly which pairs these are, let’s print out our list of stored pairs that was part of the fucntion results we stored:

# %%
for pair in pairs:
    print("Altcoin {} and Altcoin {} has a co-integration score of {}".format(pair[0],pair[1],round(pair[2],4)))
# Out:
# Altcoin ETHBTC and Altcoin LTCBTC has a co-integration score of 0.0091
# Altcoin ETHBTC and Altcoin GASBTC has a co-integration score of 0.0
# Altcoin ETHBTC and Altcoin KNCBTC has a co-integration score of 0.0224
# Altcoin ETHBTC and Altcoin OAXBTC has a co-integration score of 0.0361
# Altcoin ETHBTC and Altcoin RDNBTC has a co-integration score of 0.0126
# Altcoin ETHBTC and Altcoin AMBBTC has a co-integration score of 0.011
# Altcoin ETHBTC and Altcoin QSPBTC has a co-integration score of 0.0037
# Altcoin ETHBTC and Altcoin BCDBTC has a co-integration score of 0.0272
# Altcoin LTCBTC and Altcoin NEOBTC has a co-integration score of 0.0003
# Altcoin LTCBTC and Altcoin GASBTC has a co-integration score of 0.0002
# Altcoin LTCBTC and Altcoin QTUMBTC has a co-integration score of 0.0
# Altcoin LTCBTC and Altcoin OMGBTC has a co-integration score of 0.0
# Altcoin LTCBTC and Altcoin STRATBTC has a co-integration score of 0.0385
# Altcoin LTCBTC and Altcoin SNGLSBTC has a co-integration score of 0.0222
# Altcoin LTCBTC and Altcoin BQXBTC has a co-integration score of 0.004
# Altcoin LTCBTC and Altcoin FUNBTC has a co-integration score of 0.0477
# Altcoin LTCBTC and Altcoin LINKBTC has a co-integration score of 0.0014
# Altcoin LTCBTC and Altcoin MDABTC has a co-integration score of 0.0098
# Altcoin LTCBTC and Altcoin SNTBTC has a co-integration score of 0.0001
# Altcoin LTCBTC and Altcoin ETCBTC has a co-integration score of 0.0182
# Altcoin LTCBTC and Altcoin MTHBTC has a co-integration score of 0.0275
# Altcoin LTCBTC and Altcoin ZECBTC has a co-integration score of 0.0475
# Altcoin LTCBTC and Altcoin DASHBTC has a co-integration score of 0.0102
# Altcoin LTCBTC and Altcoin OAXBTC has a co-integration score of 0.0002
# Altcoin LTCBTC and Altcoin BTGBTC has a co-integration score of 0.003
# Altcoin LTCBTC and Altcoin EVXBTC has a co-integration score of 0.0003
# Altcoin LTCBTC and Altcoin REQBTC has a co-integration score of 0.0014
# Altcoin LTCBTC and Altcoin POWRBTC has a co-integration score of 0.0101
# Altcoin LTCBTC and Altcoin XRPBTC has a co-integration score of 0.03
# Altcoin LTCBTC and Altcoin ENJBTC has a co-integration score of 0.0001
# Altcoin LTCBTC and Altcoin STORJBTC has a co-integration score of 0.0031
# Altcoin LTCBTC and Altcoin KMDBTC has a co-integration score of 0.0103
# Altcoin LTCBTC and Altcoin RCNBTC has a co-integration score of 0.0289
# Altcoin LTCBTC and Altcoin RDNBTC has a co-integration score of 0.0027
# Altcoin LTCBTC and Altcoin XMRBTC has a co-integration score of 0.002
# Altcoin LTCBTC and Altcoin DLTBTC has a co-integration score of 0.0003
# Altcoin LTCBTC and Altcoin ARNBTC has a co-integration score of 0.004
# Altcoin LTCBTC and Altcoin CDTBTC has a co-integration score of 0.0017
# Altcoin LTCBTC and Altcoin POEBTC has a co-integration score of 0.0007
# Altcoin LTCBTC and Altcoin QSPBTC has a co-integration score of 0.0208
# Altcoin LTCBTC and Altcoin LSKBTC has a co-integration score of 0.0014
# Altcoin LTCBTC and Altcoin TNTBTC has a co-integration score of 0.0213
# Altcoin LTCBTC and Altcoin FUELBTC has a co-integration score of 0.0424
# Altcoin LTCBTC and Altcoin ADABTC has a co-integration score of 0.0004
# Altcoin BNBBTC and Altcoin MTLBTC has a co-integration score of 0.04
# Altcoin BNBBTC and Altcoin ETCBTC has a co-integration score of 0.0459
# Altcoin NEOBTC and Altcoin WTCBTC has a co-integration score of 0.043
# Altcoin NEOBTC and Altcoin LSKBTC has a co-integration score of 0.0043
# Altcoin GASBTC and Altcoin ASTBTC has a co-integration score of 0.0009
# Altcoin GASBTC and Altcoin VIBBTC has a co-integration score of 0.0056
# Altcoin GASBTC and Altcoin BCPTBTC has a co-integration score of 0.013
# Altcoin GASBTC and Altcoin LSKBTC has a co-integration score of 0.0034
# Altcoin MCOBTC and Altcoin STRATBTC has a co-integration score of 0.0421
# Altcoin MCOBTC and Altcoin FUNBTC has a co-integration score of 0.0067
# Altcoin MCOBTC and Altcoin XVGBTC has a co-integration score of 0.0081
# Altcoin MCOBTC and Altcoin MTLBTC has a co-integration score of 0.0138
# Altcoin MCOBTC and Altcoin SNTBTC has a co-integration score of 0.0205
# Altcoin MCOBTC and Altcoin MTHBTC has a co-integration score of 0.001
# Altcoin MCOBTC and Altcoin ZECBTC has a co-integration score of 0.0456
# Altcoin MCOBTC and Altcoin DASHBTC has a co-integration score of 0.0017
# Altcoin MCOBTC and Altcoin BTGBTC has a co-integration score of 0.0003
# Altcoin MCOBTC and Altcoin VIBBTC has a co-integration score of 0.0024
# Altcoin MCOBTC and Altcoin XRPBTC has a co-integration score of 0.0113
# Altcoin MCOBTC and Altcoin ENJBTC has a co-integration score of 0.0147
# Altcoin MCOBTC and Altcoin STORJBTC has a co-integration score of 0.0267
# Altcoin MCOBTC and Altcoin KMDBTC has a co-integration score of 0.0308
# Altcoin MCOBTC and Altcoin RCNBTC has a co-integration score of 0.0317
# Altcoin MCOBTC and Altcoin RDNBTC has a co-integration score of 0.0091
# Altcoin MCOBTC and Altcoin GXSBTC has a co-integration score of 0.0056
# Altcoin MCOBTC and Altcoin POEBTC has a co-integration score of 0.0395
# Altcoin MCOBTC and Altcoin BTSBTC has a co-integration score of 0.0126
# Altcoin MCOBTC and Altcoin XZCBTC has a co-integration score of 0.0311
# Altcoin MCOBTC and Altcoin TNTBTC has a co-integration score of 0.0385
# Altcoin MCOBTC and Altcoin FUELBTC has a co-integration score of 0.0459
# Altcoin MCOBTC and Altcoin ADABTC has a co-integration score of 0.0185
# Altcoin WTCBTC and Altcoin BQXBTC has a co-integration score of 0.0462
# Altcoin WTCBTC and Altcoin ENGBTC has a co-integration score of 0.0365
# Altcoin WTCBTC and Altcoin ENJBTC has a co-integration score of 0.0481
# Altcoin WTCBTC and Altcoin ARNBTC has a co-integration score of 0.039
# Altcoin LRCBTC and Altcoin OMGBTC has a co-integration score of 0.026
# Altcoin LRCBTC and Altcoin ENGBTC has a co-integration score of 0.0132
# Altcoin LRCBTC and Altcoin AMBBTC has a co-integration score of 0.0003
# Altcoin LRCBTC and Altcoin XZCBTC has a co-integration score of 0.0289
# Altcoin LRCBTC and Altcoin BCDBTC has a co-integration score of 0.015
# Altcoin QTUMBTC and Altcoin STRATBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin SNGLSBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin MDABTC has a co-integration score of 0.0001
# Altcoin QTUMBTC and Altcoin ETCBTC has a co-integration score of 0.0141
# Altcoin QTUMBTC and Altcoin MTHBTC has a co-integration score of 0.0034
# Altcoin QTUMBTC and Altcoin DNTBTC has a co-integration score of 0.047
# Altcoin QTUMBTC and Altcoin ZECBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin DASHBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin OAXBTC has a co-integration score of 0.0462
# Altcoin QTUMBTC and Altcoin BTGBTC has a co-integration score of 0.0002
# Altcoin QTUMBTC and Altcoin EVXBTC has a co-integration score of 0.0011
# Altcoin QTUMBTC and Altcoin VIBBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin POWRBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin ARKBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin STORJBTC has a co-integration score of 0.0418
# Altcoin QTUMBTC and Altcoin KMDBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin RCNBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin RDNBTC has a co-integration score of 0.0
# Altcoin QTUMBTC and Altcoin XMRBTC has a co-integration score of 0.004
# Altcoin QTUMBTC and Altcoin DLTBTC has a co-integration score of 0.0036
# Altcoin QTUMBTC and Altcoin CDTBTC has a co-integration score of 0.0012
# Altcoin QTUMBTC and Altcoin GXSBTC has a co-integration score of 0.0315
# Altcoin QTUMBTC and Altcoin QSPBTC has a co-integration score of 0.0235
# Altcoin QTUMBTC and Altcoin XZCBTC has a co-integration score of 0.0002
# Altcoin QTUMBTC and Altcoin TNTBTC has a co-integration score of 0.0365
# Altcoin QTUMBTC and Altcoin FUELBTC has a co-integration score of 0.012
# Altcoin QTUMBTC and Altcoin BCDBTC has a co-integration score of 0.0012
# Altcoin QTUMBTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin OMGBTC has a co-integration score of 0.0111
# Altcoin YOYOBTC and Altcoin STRATBTC has a co-integration score of 0.0004
# Altcoin YOYOBTC and Altcoin BQXBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin KNCBTC has a co-integration score of 0.0011
# Altcoin YOYOBTC and Altcoin FUNBTC has a co-integration score of 0.0002
# Altcoin YOYOBTC and Altcoin SNMBTC has a co-integration score of 0.0303
# Altcoin YOYOBTC and Altcoin LINKBTC has a co-integration score of 0.003
# Altcoin YOYOBTC and Altcoin XVGBTC has a co-integration score of 0.0002
# Altcoin YOYOBTC and Altcoin MDABTC has a co-integration score of 0.0095
# Altcoin YOYOBTC and Altcoin SNTBTC has a co-integration score of 0.0004
# Altcoin YOYOBTC and Altcoin ENGBTC has a co-integration score of 0.0001
# Altcoin YOYOBTC and Altcoin DNTBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin ZECBTC has a co-integration score of 0.0392
# Altcoin YOYOBTC and Altcoin BNTBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin ASTBTC has a co-integration score of 0.0011
# Altcoin YOYOBTC and Altcoin OAXBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin EVXBTC has a co-integration score of 0.0001
# Altcoin YOYOBTC and Altcoin REQBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin VIBBTC has a co-integration score of 0.0099
# Altcoin YOYOBTC and Altcoin POWRBTC has a co-integration score of 0.0048
# Altcoin YOYOBTC and Altcoin ARKBTC has a co-integration score of 0.0067
# Altcoin YOYOBTC and Altcoin XRPBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin ENJBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin KMDBTC has a co-integration score of 0.0046
# Altcoin YOYOBTC and Altcoin RCNBTC has a co-integration score of 0.0
# Altcoin YOYOBTC and Altcoin NULSBTC has a co-integration score of 0.0304
# Altcoin YOYOBTC and Altcoin RDNBTC has a co-integration score of 0.0006
# Altcoin YOYOBTC and Altcoin DLTBTC has a co-integration score of 0.0106
# Altcoin YOYOBTC and Altcoin AMBBTC has a co-integration score of 0.0001
# Altcoin YOYOBTC and Altcoin BATBTC has a co-integration score of 0.0016
# Altcoin YOYOBTC and Altcoin ARNBTC has a co-integration score of 0.0003
# Altcoin YOYOBTC and Altcoin GXSBTC has a co-integration score of 0.0028
# Altcoin YOYOBTC and Altcoin POEBTC has a co-integration score of 0.0032
# Altcoin YOYOBTC and Altcoin QSPBTC has a co-integration score of 0.0001
# Altcoin YOYOBTC and Altcoin BTSBTC has a co-integration score of 0.0004
# Altcoin YOYOBTC and Altcoin XZCBTC has a co-integration score of 0.0103
# Altcoin YOYOBTC and Altcoin LSKBTC has a co-integration score of 0.0011
# Altcoin YOYOBTC and Altcoin TNTBTC has a co-integration score of 0.0003
# Altcoin YOYOBTC and Altcoin FUELBTC has a co-integration score of 0.0001
# Altcoin YOYOBTC and Altcoin ADXBTC has a co-integration score of 0.043
# Altcoin YOYOBTC and Altcoin ADABTC has a co-integration score of 0.0
# Altcoin OMGBTC and Altcoin VIBBTC has a co-integration score of 0.0133
# Altcoin OMGBTC and Altcoin AMBBTC has a co-integration score of 0.0406
# Altcoin ZRXBTC and Altcoin NULSBTC has a co-integration score of 0.0166
# Altcoin ZRXBTC and Altcoin MANABTC has a co-integration score of 0.0287
# Altcoin STRATBTC and Altcoin SNGLSBTC has a co-integration score of 0.0
# Altcoin STRATBTC and Altcoin IOTABTC has a co-integration score of 0.032
# Altcoin STRATBTC and Altcoin MTHBTC has a co-integration score of 0.0488
# Altcoin STRATBTC and Altcoin VIBBTC has a co-integration score of 0.0083
# Altcoin STRATBTC and Altcoin ARKBTC has a co-integration score of 0.0445
# Altcoin STRATBTC and Altcoin KMDBTC has a co-integration score of 0.001
# Altcoin STRATBTC and Altcoin RCNBTC has a co-integration score of 0.0006
# Altcoin STRATBTC and Altcoin RDNBTC has a co-integration score of 0.0041
# Altcoin STRATBTC and Altcoin CDTBTC has a co-integration score of 0.048
# Altcoin STRATBTC and Altcoin XZCBTC has a co-integration score of 0.0183
# Altcoin STRATBTC and Altcoin BCDBTC has a co-integration score of 0.0432
# Altcoin STRATBTC and Altcoin ADXBTC has a co-integration score of 0.0015
# Altcoin STRATBTC and Altcoin ADABTC has a co-integration score of 0.0309
# Altcoin SNGLSBTC and Altcoin FUNBTC has a co-integration score of 0.0386
# Altcoin SNGLSBTC and Altcoin IOTABTC has a co-integration score of 0.0179
# Altcoin SNGLSBTC and Altcoin XVGBTC has a co-integration score of 0.017
# Altcoin SNGLSBTC and Altcoin MDABTC has a co-integration score of 0.0007
# Altcoin SNGLSBTC and Altcoin SNTBTC has a co-integration score of 0.0275
# Altcoin SNGLSBTC and Altcoin ZECBTC has a co-integration score of 0.0058
# Altcoin SNGLSBTC and Altcoin DASHBTC has a co-integration score of 0.0363
# Altcoin SNGLSBTC and Altcoin BTGBTC has a co-integration score of 0.0381
# Altcoin SNGLSBTC and Altcoin VIBBTC has a co-integration score of 0.0125
# Altcoin SNGLSBTC and Altcoin POWRBTC has a co-integration score of 0.0011
# Altcoin SNGLSBTC and Altcoin KMDBTC has a co-integration score of 0.0031
# Altcoin SNGLSBTC and Altcoin RCNBTC has a co-integration score of 0.0048
# Altcoin SNGLSBTC and Altcoin RDNBTC has a co-integration score of 0.0
# Altcoin SNGLSBTC and Altcoin DLTBTC has a co-integration score of 0.0381
# Altcoin SNGLSBTC and Altcoin CDTBTC has a co-integration score of 0.0208
# Altcoin SNGLSBTC and Altcoin GXSBTC has a co-integration score of 0.0288
# Altcoin SNGLSBTC and Altcoin BCDBTC has a co-integration score of 0.0046
# Altcoin SNGLSBTC and Altcoin ADABTC has a co-integration score of 0.0001
# Altcoin BQXBTC and Altcoin KNCBTC has a co-integration score of 0.0073
# Altcoin BQXBTC and Altcoin ETCBTC has a co-integration score of 0.0451
# Altcoin BQXBTC and Altcoin ENGBTC has a co-integration score of 0.0
# Altcoin BQXBTC and Altcoin ZECBTC has a co-integration score of 0.0127
# Altcoin BQXBTC and Altcoin ASTBTC has a co-integration score of 0.0269
# Altcoin BQXBTC and Altcoin OAXBTC has a co-integration score of 0.0205
# Altcoin BQXBTC and Altcoin EVXBTC has a co-integration score of 0.003
# Altcoin BQXBTC and Altcoin REQBTC has a co-integration score of 0.0212
# Altcoin BQXBTC and Altcoin ARKBTC has a co-integration score of 0.0159
# Altcoin BQXBTC and Altcoin ENJBTC has a co-integration score of 0.0
# Altcoin BQXBTC and Altcoin RCNBTC has a co-integration score of 0.0062
# Altcoin BQXBTC and Altcoin RDNBTC has a co-integration score of 0.0324
# Altcoin BQXBTC and Altcoin XMRBTC has a co-integration score of 0.0027
# Altcoin BQXBTC and Altcoin AMBBTC has a co-integration score of 0.019
# Altcoin BQXBTC and Altcoin CDTBTC has a co-integration score of 0.032
# Altcoin BQXBTC and Altcoin QSPBTC has a co-integration score of 0.0
# Altcoin BQXBTC and Altcoin XZCBTC has a co-integration score of 0.017
# Altcoin BQXBTC and Altcoin LSKBTC has a co-integration score of 0.0214
# Altcoin BQXBTC and Altcoin TNTBTC has a co-integration score of 0.0204
# Altcoin BQXBTC and Altcoin BCDBTC has a co-integration score of 0.0356
# Altcoin BQXBTC and Altcoin ADXBTC has a co-integration score of 0.0306
# Altcoin KNCBTC and Altcoin BNTBTC has a co-integration score of 0.0452
# Altcoin KNCBTC and Altcoin EVXBTC has a co-integration score of 0.007
# Altcoin KNCBTC and Altcoin VIBBTC has a co-integration score of 0.0298
# Altcoin KNCBTC and Altcoin AMBBTC has a co-integration score of 0.0337
# Altcoin KNCBTC and Altcoin QSPBTC has a co-integration score of 0.016
# Altcoin KNCBTC and Altcoin TNTBTC has a co-integration score of 0.0016
# Altcoin KNCBTC and Altcoin BCDBTC has a co-integration score of 0.0117
# Altcoin KNCBTC and Altcoin ADABTC has a co-integration score of 0.0018
# Altcoin FUNBTC and Altcoin XVGBTC has a co-integration score of 0.001
# Altcoin FUNBTC and Altcoin MTLBTC has a co-integration score of 0.041
# Altcoin FUNBTC and Altcoin SNTBTC has a co-integration score of 0.0
# Altcoin FUNBTC and Altcoin ZECBTC has a co-integration score of 0.0117
# Altcoin FUNBTC and Altcoin DASHBTC has a co-integration score of 0.0192
# Altcoin FUNBTC and Altcoin BTGBTC has a co-integration score of 0.0219
# Altcoin FUNBTC and Altcoin EVXBTC has a co-integration score of 0.015
# Altcoin FUNBTC and Altcoin VIBBTC has a co-integration score of 0.0028
# Altcoin FUNBTC and Altcoin POWRBTC has a co-integration score of 0.013
# Altcoin FUNBTC and Altcoin ARKBTC has a co-integration score of 0.0198
# Altcoin FUNBTC and Altcoin XRPBTC has a co-integration score of 0.0177
# Altcoin FUNBTC and Altcoin KMDBTC has a co-integration score of 0.0078
# Altcoin FUNBTC and Altcoin RCNBTC has a co-integration score of 0.0087
# Altcoin FUNBTC and Altcoin XMRBTC has a co-integration score of 0.0097
# Altcoin FUNBTC and Altcoin DLTBTC has a co-integration score of 0.0017
# Altcoin FUNBTC and Altcoin BTSBTC has a co-integration score of 0.022
# Altcoin FUNBTC and Altcoin XZCBTC has a co-integration score of 0.0013
# Altcoin FUNBTC and Altcoin LSKBTC has a co-integration score of 0.0103
# Altcoin FUNBTC and Altcoin TNTBTC has a co-integration score of 0.0
# Altcoin FUNBTC and Altcoin ADXBTC has a co-integration score of 0.0011
# Altcoin FUNBTC and Altcoin ADABTC has a co-integration score of 0.0139
# Altcoin SNMBTC and Altcoin IOTABTC has a co-integration score of 0.0086
# Altcoin SNMBTC and Altcoin XVGBTC has a co-integration score of 0.0292
# Altcoin SNMBTC and Altcoin ZECBTC has a co-integration score of 0.0197
# Altcoin SNMBTC and Altcoin REQBTC has a co-integration score of 0.011
# Altcoin SNMBTC and Altcoin STORJBTC has a co-integration score of 0.0298
# Altcoin SNMBTC and Altcoin KMDBTC has a co-integration score of 0.0092
# Altcoin SNMBTC and Altcoin BTSBTC has a co-integration score of 0.0022
# Altcoin SNMBTC and Altcoin XZCBTC has a co-integration score of 0.0156
# Altcoin SNMBTC and Altcoin BCDBTC has a co-integration score of 0.0411
# Altcoin SNMBTC and Altcoin ADXBTC has a co-integration score of 0.0132
# Altcoin IOTABTC and Altcoin LINKBTC has a co-integration score of 0.0064
# Altcoin IOTABTC and Altcoin XVGBTC has a co-integration score of 0.0011
# Altcoin IOTABTC and Altcoin MDABTC has a co-integration score of 0.0003
# Altcoin IOTABTC and Altcoin SNTBTC has a co-integration score of 0.0046
# Altcoin IOTABTC and Altcoin MTHBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin ENGBTC has a co-integration score of 0.0007
# Altcoin IOTABTC and Altcoin DNTBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin BNTBTC has a co-integration score of 0.0001
# Altcoin IOTABTC and Altcoin ASTBTC has a co-integration score of 0.0036
# Altcoin IOTABTC and Altcoin OAXBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin EVXBTC has a co-integration score of 0.0004
# Altcoin IOTABTC and Altcoin REQBTC has a co-integration score of 0.001
# Altcoin IOTABTC and Altcoin VIBBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin POWRBTC has a co-integration score of 0.0229
# Altcoin IOTABTC and Altcoin ARKBTC has a co-integration score of 0.0003
# Altcoin IOTABTC and Altcoin XRPBTC has a co-integration score of 0.0036
# Altcoin IOTABTC and Altcoin ENJBTC has a co-integration score of 0.0002
# Altcoin IOTABTC and Altcoin STORJBTC has a co-integration score of 0.0003
# Altcoin IOTABTC and Altcoin KMDBTC has a co-integration score of 0.0074
# Altcoin IOTABTC and Altcoin RCNBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin NULSBTC has a co-integration score of 0.0434
# Altcoin IOTABTC and Altcoin RDNBTC has a co-integration score of 0.0009
# Altcoin IOTABTC and Altcoin DLTBTC has a co-integration score of 0.0001
# Altcoin IOTABTC and Altcoin AMBBTC has a co-integration score of 0.0003
# Altcoin IOTABTC and Altcoin BATBTC has a co-integration score of 0.0031
# Altcoin IOTABTC and Altcoin BCPTBTC has a co-integration score of 0.007
# Altcoin IOTABTC and Altcoin ARNBTC has a co-integration score of 0.0019
# Altcoin IOTABTC and Altcoin CDTBTC has a co-integration score of 0.0014
# Altcoin IOTABTC and Altcoin GXSBTC has a co-integration score of 0.0002
# Altcoin IOTABTC and Altcoin POEBTC has a co-integration score of 0.0009
# Altcoin IOTABTC and Altcoin QSPBTC has a co-integration score of 0.0052
# Altcoin IOTABTC and Altcoin BTSBTC has a co-integration score of 0.0147
# Altcoin IOTABTC and Altcoin XZCBTC has a co-integration score of 0.0003
# Altcoin IOTABTC and Altcoin LSKBTC has a co-integration score of 0.0038
# Altcoin IOTABTC and Altcoin TNTBTC has a co-integration score of 0.0117
# Altcoin IOTABTC and Altcoin FUELBTC has a co-integration score of 0.0002
# Altcoin IOTABTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin IOTABTC and Altcoin ADABTC has a co-integration score of 0.002
# Altcoin LINKBTC and Altcoin SNTBTC has a co-integration score of 0.0
# Altcoin LINKBTC and Altcoin ETCBTC has a co-integration score of 0.0086
# Altcoin LINKBTC and Altcoin ZECBTC has a co-integration score of 0.0075
# Altcoin LINKBTC and Altcoin ASTBTC has a co-integration score of 0.0193
# Altcoin LINKBTC and Altcoin DASHBTC has a co-integration score of 0.0068
# Altcoin LINKBTC and Altcoin EVXBTC has a co-integration score of 0.0201
# Altcoin LINKBTC and Altcoin REQBTC has a co-integration score of 0.0472
# Altcoin LINKBTC and Altcoin VIBBTC has a co-integration score of 0.0035
# Altcoin LINKBTC and Altcoin ARKBTC has a co-integration score of 0.013
# Altcoin LINKBTC and Altcoin KMDBTC has a co-integration score of 0.0107
# Altcoin LINKBTC and Altcoin XMRBTC has a co-integration score of 0.0049
# Altcoin LINKBTC and Altcoin POEBTC has a co-integration score of 0.0052
# Altcoin LINKBTC and Altcoin XZCBTC has a co-integration score of 0.027
# Altcoin LINKBTC and Altcoin LSKBTC has a co-integration score of 0.0103
# Altcoin LINKBTC and Altcoin BCDBTC has a co-integration score of 0.0302
# Altcoin LINKBTC and Altcoin ADXBTC has a co-integration score of 0.0135
# Altcoin XVGBTC and Altcoin MDABTC has a co-integration score of 0.0001
# Altcoin XVGBTC and Altcoin MTLBTC has a co-integration score of 0.0039
# Altcoin XVGBTC and Altcoin MTHBTC has a co-integration score of 0.0004
# Altcoin XVGBTC and Altcoin ENGBTC has a co-integration score of 0.0317
# Altcoin XVGBTC and Altcoin DNTBTC has a co-integration score of 0.002
# Altcoin XVGBTC and Altcoin ZECBTC has a co-integration score of 0.0413
# Altcoin XVGBTC and Altcoin ASTBTC has a co-integration score of 0.0027
# Altcoin XVGBTC and Altcoin DASHBTC has a co-integration score of 0.0178
# Altcoin XVGBTC and Altcoin OAXBTC has a co-integration score of 0.0023
# Altcoin XVGBTC and Altcoin BTGBTC has a co-integration score of 0.0004
# Altcoin XVGBTC and Altcoin EVXBTC has a co-integration score of 0.0447
# Altcoin XVGBTC and Altcoin REQBTC has a co-integration score of 0.0016
# Altcoin XVGBTC and Altcoin VIBBTC has a co-integration score of 0.0048
# Altcoin XVGBTC and Altcoin POWRBTC has a co-integration score of 0.0116
# Altcoin XVGBTC and Altcoin ARKBTC has a co-integration score of 0.0001
# Altcoin XVGBTC and Altcoin ENJBTC has a co-integration score of 0.0158
# Altcoin XVGBTC and Altcoin STORJBTC has a co-integration score of 0.0
# Altcoin XVGBTC and Altcoin KMDBTC has a co-integration score of 0.0096
# Altcoin XVGBTC and Altcoin RCNBTC has a co-integration score of 0.0013
# Altcoin XVGBTC and Altcoin RDNBTC has a co-integration score of 0.0007
# Altcoin XVGBTC and Altcoin XMRBTC has a co-integration score of 0.0204
# Altcoin XVGBTC and Altcoin DLTBTC has a co-integration score of 0.0017
# Altcoin XVGBTC and Altcoin AMBBTC has a co-integration score of 0.0178
# Altcoin XVGBTC and Altcoin BCPTBTC has a co-integration score of 0.023
# Altcoin XVGBTC and Altcoin CDTBTC has a co-integration score of 0.0005
# Altcoin XVGBTC and Altcoin GXSBTC has a co-integration score of 0.0315
# Altcoin XVGBTC and Altcoin POEBTC has a co-integration score of 0.0099
# Altcoin XVGBTC and Altcoin QSPBTC has a co-integration score of 0.0026
# Altcoin XVGBTC and Altcoin XZCBTC has a co-integration score of 0.0287
# Altcoin XVGBTC and Altcoin TNTBTC has a co-integration score of 0.0218
# Altcoin XVGBTC and Altcoin FUELBTC has a co-integration score of 0.013
# Altcoin XVGBTC and Altcoin BCDBTC has a co-integration score of 0.0229
# Altcoin XVGBTC and Altcoin ADXBTC has a co-integration score of 0.002
# Altcoin MDABTC and Altcoin MTHBTC has a co-integration score of 0.0098
# Altcoin MDABTC and Altcoin ZECBTC has a co-integration score of 0.0248
# Altcoin MDABTC and Altcoin DASHBTC has a co-integration score of 0.008
# Altcoin MDABTC and Altcoin BTGBTC has a co-integration score of 0.02
# Altcoin MDABTC and Altcoin VIBBTC has a co-integration score of 0.0122
# Altcoin MDABTC and Altcoin POWRBTC has a co-integration score of 0.0335
# Altcoin MDABTC and Altcoin ARKBTC has a co-integration score of 0.0148
# Altcoin MDABTC and Altcoin KMDBTC has a co-integration score of 0.0018
# Altcoin MDABTC and Altcoin RCNBTC has a co-integration score of 0.0
# Altcoin MDABTC and Altcoin RDNBTC has a co-integration score of 0.0152
# Altcoin MDABTC and Altcoin XZCBTC has a co-integration score of 0.007
# Altcoin MDABTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin MDABTC and Altcoin ADABTC has a co-integration score of 0.0047
# Altcoin SNTBTC and Altcoin ZECBTC has a co-integration score of 0.0152
# Altcoin SNTBTC and Altcoin BNTBTC has a co-integration score of 0.0221
# Altcoin SNTBTC and Altcoin ASTBTC has a co-integration score of 0.0046
# Altcoin SNTBTC and Altcoin DASHBTC has a co-integration score of 0.0297
# Altcoin SNTBTC and Altcoin EVXBTC has a co-integration score of 0.0004
# Altcoin SNTBTC and Altcoin REQBTC has a co-integration score of 0.0
# Altcoin SNTBTC and Altcoin ARKBTC has a co-integration score of 0.0207
# Altcoin SNTBTC and Altcoin ENJBTC has a co-integration score of 0.0
# Altcoin SNTBTC and Altcoin KMDBTC has a co-integration score of 0.0457
# Altcoin SNTBTC and Altcoin RCNBTC has a co-integration score of 0.0397
# Altcoin SNTBTC and Altcoin RDNBTC has a co-integration score of 0.0388
# Altcoin SNTBTC and Altcoin DLTBTC has a co-integration score of 0.0001
# Altcoin SNTBTC and Altcoin CDTBTC has a co-integration score of 0.0196
# Altcoin SNTBTC and Altcoin POEBTC has a co-integration score of 0.0
# Altcoin SNTBTC and Altcoin XZCBTC has a co-integration score of 0.0256
# Altcoin SNTBTC and Altcoin LSKBTC has a co-integration score of 0.0113
# Altcoin SNTBTC and Altcoin TNTBTC has a co-integration score of 0.0108
# Altcoin SNTBTC and Altcoin FUELBTC has a co-integration score of 0.0018
# Altcoin SNTBTC and Altcoin BCDBTC has a co-integration score of 0.0309
# Altcoin SNTBTC and Altcoin ADXBTC has a co-integration score of 0.0028
# Altcoin SNTBTC and Altcoin ADABTC has a co-integration score of 0.0092
# Altcoin ETCBTC and Altcoin ZECBTC has a co-integration score of 0.0042
# Altcoin ETCBTC and Altcoin BTGBTC has a co-integration score of 0.0407
# Altcoin ETCBTC and Altcoin VIBBTC has a co-integration score of 0.0419
# Altcoin ETCBTC and Altcoin ARKBTC has a co-integration score of 0.0181
# Altcoin ETCBTC and Altcoin XRPBTC has a co-integration score of 0.0377
# Altcoin ETCBTC and Altcoin RCNBTC has a co-integration score of 0.0417
# Altcoin ETCBTC and Altcoin RDNBTC has a co-integration score of 0.0383
# Altcoin ETCBTC and Altcoin XMRBTC has a co-integration score of 0.0186
# Altcoin ETCBTC and Altcoin DLTBTC has a co-integration score of 0.0072
# Altcoin ETCBTC and Altcoin GXSBTC has a co-integration score of 0.0391
# Altcoin ETCBTC and Altcoin XZCBTC has a co-integration score of 0.0041
# Altcoin ETCBTC and Altcoin LSKBTC has a co-integration score of 0.0258
# Altcoin ETCBTC and Altcoin TNTBTC has a co-integration score of 0.0323
# Altcoin ETCBTC and Altcoin BCDBTC has a co-integration score of 0.007
# Altcoin ETCBTC and Altcoin ADXBTC has a co-integration score of 0.0132
# Altcoin ETCBTC and Altcoin ADABTC has a co-integration score of 0.0268
# Altcoin MTHBTC and Altcoin ZECBTC has a co-integration score of 0.0195
# Altcoin MTHBTC and Altcoin ASTBTC has a co-integration score of 0.0209
# Altcoin MTHBTC and Altcoin DASHBTC has a co-integration score of 0.0297
# Altcoin MTHBTC and Altcoin BTGBTC has a co-integration score of 0.0435
# Altcoin MTHBTC and Altcoin EVXBTC has a co-integration score of 0.0097
# Altcoin MTHBTC and Altcoin VIBBTC has a co-integration score of 0.0
# Altcoin MTHBTC and Altcoin POWRBTC has a co-integration score of 0.0351
# Altcoin MTHBTC and Altcoin ARKBTC has a co-integration score of 0.0183
# Altcoin MTHBTC and Altcoin STORJBTC has a co-integration score of 0.0003
# Altcoin MTHBTC and Altcoin KMDBTC has a co-integration score of 0.0024
# Altcoin MTHBTC and Altcoin RCNBTC has a co-integration score of 0.0207
# Altcoin MTHBTC and Altcoin RDNBTC has a co-integration score of 0.001
# Altcoin MTHBTC and Altcoin XMRBTC has a co-integration score of 0.0352
# Altcoin MTHBTC and Altcoin DLTBTC has a co-integration score of 0.0004
# Altcoin MTHBTC and Altcoin CDTBTC has a co-integration score of 0.0403
# Altcoin MTHBTC and Altcoin GXSBTC has a co-integration score of 0.0025
# Altcoin MTHBTC and Altcoin XZCBTC has a co-integration score of 0.0058
# Altcoin MTHBTC and Altcoin LSKBTC has a co-integration score of 0.0461
# Altcoin MTHBTC and Altcoin BCDBTC has a co-integration score of 0.0456
# Altcoin MTHBTC and Altcoin ADXBTC has a co-integration score of 0.0031
# Altcoin ENGBTC and Altcoin ZECBTC has a co-integration score of 0.0242
# Altcoin ENGBTC and Altcoin BNTBTC has a co-integration score of 0.0051
# Altcoin ENGBTC and Altcoin ASTBTC has a co-integration score of 0.0066
# Altcoin ENGBTC and Altcoin DASHBTC has a co-integration score of 0.0027
# Altcoin ENGBTC and Altcoin BTGBTC has a co-integration score of 0.0143
# Altcoin ENGBTC and Altcoin EVXBTC has a co-integration score of 0.0284
# Altcoin ENGBTC and Altcoin VIBBTC has a co-integration score of 0.0296
# Altcoin ENGBTC and Altcoin ARKBTC has a co-integration score of 0.0179
# Altcoin ENGBTC and Altcoin RCNBTC has a co-integration score of 0.015
# Altcoin ENGBTC and Altcoin RDNBTC has a co-integration score of 0.0265
# Altcoin ENGBTC and Altcoin XMRBTC has a co-integration score of 0.0007
# Altcoin ENGBTC and Altcoin AMBBTC has a co-integration score of 0.0012
# Altcoin ENGBTC and Altcoin CDTBTC has a co-integration score of 0.032
# Altcoin ENGBTC and Altcoin QSPBTC has a co-integration score of 0.0003
# Altcoin ENGBTC and Altcoin BTSBTC has a co-integration score of 0.0009
# Altcoin ENGBTC and Altcoin XZCBTC has a co-integration score of 0.0148
# Altcoin ENGBTC and Altcoin TNTBTC has a co-integration score of 0.0124
# Altcoin ENGBTC and Altcoin BCDBTC has a co-integration score of 0.0118
# Altcoin DNTBTC and Altcoin ZECBTC has a co-integration score of 0.0016
# Altcoin DNTBTC and Altcoin ASTBTC has a co-integration score of 0.0007
# Altcoin DNTBTC and Altcoin DASHBTC has a co-integration score of 0.0036
# Altcoin DNTBTC and Altcoin BTGBTC has a co-integration score of 0.0164
# Altcoin DNTBTC and Altcoin EVXBTC has a co-integration score of 0.045
# Altcoin DNTBTC and Altcoin VIBBTC has a co-integration score of 0.0078
# Altcoin DNTBTC and Altcoin POWRBTC has a co-integration score of 0.0478
# Altcoin DNTBTC and Altcoin ARKBTC has a co-integration score of 0.0176
# Altcoin DNTBTC and Altcoin XRPBTC has a co-integration score of 0.0
# Altcoin DNTBTC and Altcoin STORJBTC has a co-integration score of 0.0487
# Altcoin DNTBTC and Altcoin KMDBTC has a co-integration score of 0.0233
# Altcoin DNTBTC and Altcoin RCNBTC has a co-integration score of 0.033
# Altcoin DNTBTC and Altcoin RDNBTC has a co-integration score of 0.0319
# Altcoin DNTBTC and Altcoin XMRBTC has a co-integration score of 0.0081
# Altcoin DNTBTC and Altcoin DLTBTC has a co-integration score of 0.0224
# Altcoin DNTBTC and Altcoin GXSBTC has a co-integration score of 0.0181
# Altcoin DNTBTC and Altcoin BTSBTC has a co-integration score of 0.0026
# Altcoin DNTBTC and Altcoin XZCBTC has a co-integration score of 0.013
# Altcoin DNTBTC and Altcoin TNTBTC has a co-integration score of 0.0008
# Altcoin DNTBTC and Altcoin ADABTC has a co-integration score of 0.0102
# Altcoin ZECBTC and Altcoin DASHBTC has a co-integration score of 0.0239
# Altcoin ZECBTC and Altcoin BTGBTC has a co-integration score of 0.0366
# Altcoin ZECBTC and Altcoin VIBBTC has a co-integration score of 0.0089
# Altcoin ZECBTC and Altcoin POWRBTC has a co-integration score of 0.0428
# Altcoin ZECBTC and Altcoin ARKBTC has a co-integration score of 0.01
# Altcoin ZECBTC and Altcoin KMDBTC has a co-integration score of 0.0212
# Altcoin ZECBTC and Altcoin RCNBTC has a co-integration score of 0.0014
# Altcoin ZECBTC and Altcoin RDNBTC has a co-integration score of 0.0011
# Altcoin ZECBTC and Altcoin XMRBTC has a co-integration score of 0.0451
# Altcoin ZECBTC and Altcoin DLTBTC has a co-integration score of 0.046
# Altcoin ZECBTC and Altcoin CDTBTC has a co-integration score of 0.0397
# Altcoin ZECBTC and Altcoin GXSBTC has a co-integration score of 0.0186
# Altcoin ZECBTC and Altcoin XZCBTC has a co-integration score of 0.0
# Altcoin ZECBTC and Altcoin BCDBTC has a co-integration score of 0.0041
# Altcoin ZECBTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin BNTBTC and Altcoin RDNBTC has a co-integration score of 0.0069
# Altcoin BNTBTC and Altcoin QSPBTC has a co-integration score of 0.0056
# Altcoin BNTBTC and Altcoin BCDBTC has a co-integration score of 0.0439
# Altcoin ASTBTC and Altcoin EVXBTC has a co-integration score of 0.0027
# Altcoin ASTBTC and Altcoin VIBBTC has a co-integration score of 0.0072
# Altcoin ASTBTC and Altcoin POWRBTC has a co-integration score of 0.036
# Altcoin ASTBTC and Altcoin STORJBTC has a co-integration score of 0.0108
# Altcoin ASTBTC and Altcoin KMDBTC has a co-integration score of 0.0098
# Altcoin ASTBTC and Altcoin XMRBTC has a co-integration score of 0.0372
# Altcoin ASTBTC and Altcoin AMBBTC has a co-integration score of 0.0496
# Altcoin ASTBTC and Altcoin POEBTC has a co-integration score of 0.0248
# Altcoin ASTBTC and Altcoin LSKBTC has a co-integration score of 0.0079
# Altcoin ASTBTC and Altcoin TNTBTC has a co-integration score of 0.0262
# Altcoin ASTBTC and Altcoin ADABTC has a co-integration score of 0.0254
# Altcoin DASHBTC and Altcoin VIBBTC has a co-integration score of 0.0222
# Altcoin DASHBTC and Altcoin POWRBTC has a co-integration score of 0.006
# Altcoin DASHBTC and Altcoin ARKBTC has a co-integration score of 0.0073
# Altcoin DASHBTC and Altcoin KMDBTC has a co-integration score of 0.0153
# Altcoin DASHBTC and Altcoin RDNBTC has a co-integration score of 0.0151
# Altcoin DASHBTC and Altcoin DLTBTC has a co-integration score of 0.0229
# Altcoin DASHBTC and Altcoin XZCBTC has a co-integration score of 0.0245
# Altcoin DASHBTC and Altcoin FUELBTC has a co-integration score of 0.0216
# Altcoin DASHBTC and Altcoin ADXBTC has a co-integration score of 0.0054
# Altcoin OAXBTC and Altcoin EVXBTC has a co-integration score of 0.0231
# Altcoin OAXBTC and Altcoin VIBBTC has a co-integration score of 0.0062
# Altcoin OAXBTC and Altcoin ENJBTC has a co-integration score of 0.0006
# Altcoin OAXBTC and Altcoin STORJBTC has a co-integration score of 0.0309
# Altcoin OAXBTC and Altcoin XMRBTC has a co-integration score of 0.0042
# Altcoin OAXBTC and Altcoin CDTBTC has a co-integration score of 0.0102
# Altcoin OAXBTC and Altcoin GXSBTC has a co-integration score of 0.0246
# Altcoin OAXBTC and Altcoin BTSBTC has a co-integration score of 0.0249
# Altcoin OAXBTC and Altcoin BCDBTC has a co-integration score of 0.0214
# Altcoin BTGBTC and Altcoin EVXBTC has a co-integration score of 0.0319
# Altcoin BTGBTC and Altcoin REQBTC has a co-integration score of 0.0013
# Altcoin BTGBTC and Altcoin VIBBTC has a co-integration score of 0.0093
# Altcoin BTGBTC and Altcoin POWRBTC has a co-integration score of 0.0002
# Altcoin BTGBTC and Altcoin ARKBTC has a co-integration score of 0.0001
# Altcoin BTGBTC and Altcoin XRPBTC has a co-integration score of 0.0027
# Altcoin BTGBTC and Altcoin STORJBTC has a co-integration score of 0.0007
# Altcoin BTGBTC and Altcoin KMDBTC has a co-integration score of 0.0
# Altcoin BTGBTC and Altcoin RCNBTC has a co-integration score of 0.0079
# Altcoin BTGBTC and Altcoin XMRBTC has a co-integration score of 0.0002
# Altcoin BTGBTC and Altcoin AMBBTC has a co-integration score of 0.027
# Altcoin BTGBTC and Altcoin BATBTC has a co-integration score of 0.0383
# Altcoin BTGBTC and Altcoin GXSBTC has a co-integration score of 0.0001
# Altcoin BTGBTC and Altcoin QSPBTC has a co-integration score of 0.0052
# Altcoin BTGBTC and Altcoin BTSBTC has a co-integration score of 0.0057
# Altcoin BTGBTC and Altcoin XZCBTC has a co-integration score of 0.0
# Altcoin BTGBTC and Altcoin LSKBTC has a co-integration score of 0.0096
# Altcoin BTGBTC and Altcoin TNTBTC has a co-integration score of 0.0073
# Altcoin BTGBTC and Altcoin FUELBTC has a co-integration score of 0.0013
# Altcoin BTGBTC and Altcoin ADXBTC has a co-integration score of 0.0094
# Altcoin BTGBTC and Altcoin ADABTC has a co-integration score of 0.0004
# Altcoin EVXBTC and Altcoin REQBTC has a co-integration score of 0.0275
# Altcoin EVXBTC and Altcoin VIBBTC has a co-integration score of 0.0053
# Altcoin EVXBTC and Altcoin ARKBTC has a co-integration score of 0.002
# Altcoin EVXBTC and Altcoin XRPBTC has a co-integration score of 0.0168
# Altcoin EVXBTC and Altcoin KMDBTC has a co-integration score of 0.0034
# Altcoin EVXBTC and Altcoin RCNBTC has a co-integration score of 0.0098
# Altcoin EVXBTC and Altcoin RDNBTC has a co-integration score of 0.0211
# Altcoin EVXBTC and Altcoin XMRBTC has a co-integration score of 0.0013
# Altcoin EVXBTC and Altcoin CDTBTC has a co-integration score of 0.0112
# Altcoin EVXBTC and Altcoin GXSBTC has a co-integration score of 0.0167
# Altcoin EVXBTC and Altcoin POEBTC has a co-integration score of 0.0051
# Altcoin EVXBTC and Altcoin QSPBTC has a co-integration score of 0.0
# Altcoin EVXBTC and Altcoin BTSBTC has a co-integration score of 0.0104
# Altcoin EVXBTC and Altcoin XZCBTC has a co-integration score of 0.0131
# Altcoin EVXBTC and Altcoin LSKBTC has a co-integration score of 0.0021
# Altcoin EVXBTC and Altcoin TNTBTC has a co-integration score of 0.0068
# Altcoin EVXBTC and Altcoin FUELBTC has a co-integration score of 0.0007
# Altcoin EVXBTC and Altcoin BCDBTC has a co-integration score of 0.0062
# Altcoin EVXBTC and Altcoin ADXBTC has a co-integration score of 0.0189
# Altcoin REQBTC and Altcoin VIBBTC has a co-integration score of 0.0
# Altcoin REQBTC and Altcoin ARKBTC has a co-integration score of 0.0247
# Altcoin REQBTC and Altcoin RCNBTC has a co-integration score of 0.0027
# Altcoin REQBTC and Altcoin RDNBTC has a co-integration score of 0.0474
# Altcoin REQBTC and Altcoin XMRBTC has a co-integration score of 0.0027
# Altcoin REQBTC and Altcoin DLTBTC has a co-integration score of 0.0001
# Altcoin REQBTC and Altcoin BTSBTC has a co-integration score of 0.0281
# Altcoin REQBTC and Altcoin XZCBTC has a co-integration score of 0.0208
# Altcoin REQBTC and Altcoin ADXBTC has a co-integration score of 0.0033
# Altcoin VIBBTC and Altcoin POWRBTC has a co-integration score of 0.0003
# Altcoin VIBBTC and Altcoin ARKBTC has a co-integration score of 0.0
# Altcoin VIBBTC and Altcoin STORJBTC has a co-integration score of 0.0279
# Altcoin VIBBTC and Altcoin RCNBTC has a co-integration score of 0.0
# Altcoin VIBBTC and Altcoin RDNBTC has a co-integration score of 0.0
# Altcoin VIBBTC and Altcoin XMRBTC has a co-integration score of 0.0282
# Altcoin VIBBTC and Altcoin DLTBTC has a co-integration score of 0.0002
# Altcoin VIBBTC and Altcoin CDTBTC has a co-integration score of 0.0004
# Altcoin VIBBTC and Altcoin GXSBTC has a co-integration score of 0.0157
# Altcoin VIBBTC and Altcoin QSPBTC has a co-integration score of 0.0003
# Altcoin VIBBTC and Altcoin TNTBTC has a co-integration score of 0.0003
# Altcoin VIBBTC and Altcoin FUELBTC has a co-integration score of 0.0145
# Altcoin VIBBTC and Altcoin BCDBTC has a co-integration score of 0.0093
# Altcoin VIBBTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin TRXBTC and Altcoin KMDBTC has a co-integration score of 0.0434
# Altcoin TRXBTC and Altcoin NULSBTC has a co-integration score of 0.0001
# Altcoin TRXBTC and Altcoin BATBTC has a co-integration score of 0.0309
# Altcoin TRXBTC and Altcoin ARNBTC has a co-integration score of 0.0369
# Altcoin TRXBTC and Altcoin MANABTC has a co-integration score of 0.0001
# Altcoin POWRBTC and Altcoin KMDBTC has a co-integration score of 0.0082
# Altcoin POWRBTC and Altcoin CDTBTC has a co-integration score of 0.0303
# Altcoin POWRBTC and Altcoin XZCBTC has a co-integration score of 0.0463
# Altcoin POWRBTC and Altcoin BCDBTC has a co-integration score of 0.0022
# Altcoin POWRBTC and Altcoin ADXBTC has a co-integration score of 0.0013
# Altcoin POWRBTC and Altcoin ADABTC has a co-integration score of 0.0047
# Altcoin ARKBTC and Altcoin STORJBTC has a co-integration score of 0.0096
# Altcoin ARKBTC and Altcoin KMDBTC has a co-integration score of 0.0001
# Altcoin ARKBTC and Altcoin RDNBTC has a co-integration score of 0.0011
# Altcoin ARKBTC and Altcoin XZCBTC has a co-integration score of 0.0003
# Altcoin ARKBTC and Altcoin BCDBTC has a co-integration score of 0.0161
# Altcoin ARKBTC and Altcoin ADXBTC has a co-integration score of 0.003
# Altcoin XRPBTC and Altcoin STORJBTC has a co-integration score of 0.0441
# Altcoin XRPBTC and Altcoin KMDBTC has a co-integration score of 0.0097
# Altcoin XRPBTC and Altcoin RCNBTC has a co-integration score of 0.01
# Altcoin XRPBTC and Altcoin RDNBTC has a co-integration score of 0.001
# Altcoin XRPBTC and Altcoin XMRBTC has a co-integration score of 0.0113
# Altcoin XRPBTC and Altcoin DLTBTC has a co-integration score of 0.0073
# Altcoin XRPBTC and Altcoin AMBBTC has a co-integration score of 0.0472
# Altcoin XRPBTC and Altcoin CDTBTC has a co-integration score of 0.0324
# Altcoin XRPBTC and Altcoin GXSBTC has a co-integration score of 0.0203
# Altcoin XRPBTC and Altcoin POEBTC has a co-integration score of 0.0419
# Altcoin XRPBTC and Altcoin QSPBTC has a co-integration score of 0.0073
# Altcoin XRPBTC and Altcoin XZCBTC has a co-integration score of 0.0239
# Altcoin XRPBTC and Altcoin TNTBTC has a co-integration score of 0.0065
# Altcoin XRPBTC and Altcoin FUELBTC has a co-integration score of 0.0476
# Altcoin XRPBTC and Altcoin BCDBTC has a co-integration score of 0.0083
# Altcoin XRPBTC and Altcoin ADXBTC has a co-integration score of 0.0165
# Altcoin XRPBTC and Altcoin ADABTC has a co-integration score of 0.0004
# Altcoin ENJBTC and Altcoin STORJBTC has a co-integration score of 0.0028
# Altcoin ENJBTC and Altcoin RDNBTC has a co-integration score of 0.0166
# Altcoin ENJBTC and Altcoin XMRBTC has a co-integration score of 0.0339
# Altcoin ENJBTC and Altcoin AMBBTC has a co-integration score of 0.0419
# Altcoin ENJBTC and Altcoin ARNBTC has a co-integration score of 0.0443
# Altcoin ENJBTC and Altcoin POEBTC has a co-integration score of 0.0367
# Altcoin ENJBTC and Altcoin QSPBTC has a co-integration score of 0.0
# Altcoin ENJBTC and Altcoin TNTBTC has a co-integration score of 0.0487
# Altcoin ENJBTC and Altcoin BCDBTC has a co-integration score of 0.0287
# Altcoin STORJBTC and Altcoin KMDBTC has a co-integration score of 0.0003
# Altcoin STORJBTC and Altcoin XZCBTC has a co-integration score of 0.0143
# Altcoin STORJBTC and Altcoin BCDBTC has a co-integration score of 0.0199
# Altcoin KMDBTC and Altcoin RCNBTC has a co-integration score of 0.0001
# Altcoin KMDBTC and Altcoin RDNBTC has a co-integration score of 0.0002
# Altcoin KMDBTC and Altcoin XMRBTC has a co-integration score of 0.0276
# Altcoin KMDBTC and Altcoin DLTBTC has a co-integration score of 0.0105
# Altcoin KMDBTC and Altcoin QSPBTC has a co-integration score of 0.0378
# Altcoin KMDBTC and Altcoin TNTBTC has a co-integration score of 0.0094
# Altcoin KMDBTC and Altcoin FUELBTC has a co-integration score of 0.0099
# Altcoin KMDBTC and Altcoin BCDBTC has a co-integration score of 0.0337
# Altcoin KMDBTC and Altcoin ADXBTC has a co-integration score of 0.0
# Altcoin RCNBTC and Altcoin RDNBTC has a co-integration score of 0.0025
# Altcoin RCNBTC and Altcoin GXSBTC has a co-integration score of 0.0115
# Altcoin RCNBTC and Altcoin XZCBTC has a co-integration score of 0.0475
# Altcoin RCNBTC and Altcoin ADXBTC has a co-integration score of 0.0237
# Altcoin NULSBTC and Altcoin BCDBTC has a co-integration score of 0.0401
# Altcoin RDNBTC and Altcoin CDTBTC has a co-integration score of 0.0061
# Altcoin RDNBTC and Altcoin XZCBTC has a co-integration score of 0.0002
# Altcoin RDNBTC and Altcoin BCDBTC has a co-integration score of 0.0135
# Altcoin RDNBTC and Altcoin ADXBTC has a co-integration score of 0.0001
# Altcoin XMRBTC and Altcoin QSPBTC has a co-integration score of 0.04
# Altcoin XMRBTC and Altcoin XZCBTC has a co-integration score of 0.002
# Altcoin XMRBTC and Altcoin BCDBTC has a co-integration score of 0.03
# Altcoin XMRBTC and Altcoin ADXBTC has a co-integration score of 0.0345
# Altcoin DLTBTC and Altcoin CDTBTC has a co-integration score of 0.0065
# Altcoin DLTBTC and Altcoin BTSBTC has a co-integration score of 0.0083
# Altcoin DLTBTC and Altcoin XZCBTC has a co-integration score of 0.0187
# Altcoin DLTBTC and Altcoin LSKBTC has a co-integration score of 0.0319
# Altcoin DLTBTC and Altcoin TNTBTC has a co-integration score of 0.0198
# Altcoin DLTBTC and Altcoin FUELBTC has a co-integration score of 0.0321
# Altcoin DLTBTC and Altcoin BCDBTC has a co-integration score of 0.0048
# Altcoin DLTBTC and Altcoin ADABTC has a co-integration score of 0.016
# Altcoin AMBBTC and Altcoin QSPBTC has a co-integration score of 0.0217
# Altcoin BATBTC and Altcoin CDTBTC has a co-integration score of 0.0476
# Altcoin BATBTC and Altcoin XZCBTC has a co-integration score of 0.0141
# Altcoin BATBTC and Altcoin TNTBTC has a co-integration score of 0.0027
# Altcoin BATBTC and Altcoin BCDBTC has a co-integration score of 0.0051
# Altcoin BATBTC and Altcoin ADXBTC has a co-integration score of 0.0449
# Altcoin BATBTC and Altcoin ADABTC has a co-integration score of 0.0092
# Altcoin BCPTBTC and Altcoin LSKBTC has a co-integration score of 0.0044
# Altcoin BCPTBTC and Altcoin BCDBTC has a co-integration score of 0.0464
# Altcoin ARNBTC and Altcoin POEBTC has a co-integration score of 0.0069
# Altcoin ARNBTC and Altcoin QSPBTC has a co-integration score of 0.0001
# Altcoin ARNBTC and Altcoin LSKBTC has a co-integration score of 0.0014
# Altcoin ARNBTC and Altcoin TNTBTC has a co-integration score of 0.0031
# Altcoin ARNBTC and Altcoin FUELBTC has a co-integration score of 0.0026
# Altcoin ARNBTC and Altcoin BCDBTC has a co-integration score of 0.0419
# Altcoin ARNBTC and Altcoin ADXBTC has a co-integration score of 0.0331
# Altcoin ARNBTC and Altcoin ADABTC has a co-integration score of 0.0293
# Altcoin GVTBTC and Altcoin DGDBTC has a co-integration score of 0.001
# Altcoin CDTBTC and Altcoin POEBTC has a co-integration score of 0.0258
# Altcoin CDTBTC and Altcoin XZCBTC has a co-integration score of 0.0196
# Altcoin CDTBTC and Altcoin TNTBTC has a co-integration score of 0.0371
# Altcoin CDTBTC and Altcoin BCDBTC has a co-integration score of 0.0001
# Altcoin CDTBTC and Altcoin ADXBTC has a co-integration score of 0.0111
# Altcoin CDTBTC and Altcoin ADABTC has a co-integration score of 0.018
# Altcoin GXSBTC and Altcoin POEBTC has a co-integration score of 0.0018
# Altcoin GXSBTC and Altcoin QSPBTC has a co-integration score of 0.0038
# Altcoin GXSBTC and Altcoin XZCBTC has a co-integration score of 0.0002
# Altcoin GXSBTC and Altcoin TNTBTC has a co-integration score of 0.0118
# Altcoin GXSBTC and Altcoin BCDBTC has a co-integration score of 0.0019
# Altcoin GXSBTC and Altcoin ADXBTC has a co-integration score of 0.0001
# Altcoin POEBTC and Altcoin QSPBTC has a co-integration score of 0.0311
# Altcoin POEBTC and Altcoin BTSBTC has a co-integration score of 0.0488
# Altcoin POEBTC and Altcoin TNTBTC has a co-integration score of 0.0005
# Altcoin POEBTC and Altcoin FUELBTC has a co-integration score of 0.0365
# Altcoin POEBTC and Altcoin BCDBTC has a co-integration score of 0.0344
# Altcoin QSPBTC and Altcoin BTSBTC has a co-integration score of 0.0417
# Altcoin QSPBTC and Altcoin XZCBTC has a co-integration score of 0.0188
# Altcoin QSPBTC and Altcoin BCDBTC has a co-integration score of 0.0052
# Altcoin BTSBTC and Altcoin TNTBTC has a co-integration score of 0.0146
# Altcoin BTSBTC and Altcoin FUELBTC has a co-integration score of 0.0405
# Altcoin BTSBTC and Altcoin BCDBTC has a co-integration score of 0.0041
# Altcoin XZCBTC and Altcoin BCDBTC has a co-integration score of 0.0045
# Altcoin XZCBTC and Altcoin ADXBTC has a co-integration score of 0.0001
# Altcoin LSKBTC and Altcoin BCDBTC has a co-integration score of 0.0281
# Altcoin FUELBTC and Altcoin BCDBTC has a co-integration score of 0.0007
# Altcoin FUELBTC and Altcoin ADXBTC has a co-integration score of 0.0177
# Altcoin MANABTC and Altcoin BCDBTC has a co-integration score of 0.0038
# Altcoin MANABTC and Altcoin DGDBTC has a co-integration score of 0.0134
# Altcoin MANABTC and Altcoin ADXBTC has a co-integration score of 0.0032
# Altcoin MANABTC and Altcoin ADABTC has a co-integration score of 0.0011
# Altcoin BCDBTC and Altcoin ADXBTC has a co-integration score of 0.0046
# Altcoin BCDBTC and Altcoin ADABTC has a co-integration score of 0.0008

# %% [markdown]
# We will now use the “pykalman” module to set up a couple of functions that will allow us to generate Kalman filters which we will apply to our data and in turn our regression that is fed the said data.

# %%
def KalmanFilterAverage(x):
  # Construct a Kalman filter
    kf = KalmanFilter(transition_matrices = [1],
    observation_matrices = [1],
    initial_state_mean = 0,
    initial_state_covariance = 1,
    observation_covariance=1,
    transition_covariance=.01)
  # Use the observed values of the price to get a rolling mean
    state_means, _ = kf.filter(x.values)
    state_means = pd.Series(state_means.flatten(), index=x.index)
    return state_means

# Kalman filter regression
def KalmanFilterRegression(x,y):
    delta = 1e-3
    trans_cov = delta / (1 - delta) * np.eye(2) # How much random walk wiggles
    obs_mat = np.expand_dims(np.vstack([[x], [np.ones(len(x))]]).T, axis=1)
    kf = KalmanFilter(n_dim_obs=1, n_dim_state=2, # y is 1-dimensional, (alpha, beta) is 2-dimensional
    initial_state_mean=[0,0],
    initial_state_covariance=np.ones((2, 2)),
    transition_matrices=np.eye(2),
    observation_matrices=obs_mat,
    observation_covariance=2,
    transition_covariance=trans_cov)
    # Use the observations y to get running estimates and errors for the state parameters
    state_means, state_covs = kf.filter(y.values)
    return state_means

def half_life(spread):
    spread_lag = spread.shift(1)
    spread_lag.iloc[0] = spread_lag.iloc[1]
    spread_ret = spread - spread_lag
    spread_ret.iloc[0] = spread_ret.iloc[1]
    spread_lag2 = sm.add_constant(spread_lag)
    model = sm.OLS(spread_ret,spread_lag2)
    res = model.fit()
    halflife = int(round(-np.log(2) / res.params[1],0))
    if halflife <= 0:
        halflife = 1
    return halflife

# %% [markdown]
# Now let us define our main “Backtest” function that we will run our data through. The fucntion takes one pair of tickers at a time, and then returns several outputs, namely the DataFrame of cumulative returns,
# the Sharpe Ratio and the Compound Annual Growth Rate (CAGR). Once we have defined our function, we can iterate over our list of pairs and feed the relevant data, pair by pair, into the function, storing the outputs for each pair for
# later use and retrieval.

# %%
def backtest(df,s1, s2):
    #############################################################
    # INPUT:
    # DataFrame of prices
    # s1: the symbol of contract one
    # s2: the symbol of contract two
    # x: the price series of contract one
    # y: the price series of contract two
    # OUTPUT:
    # df1['cum rets']: cumulative returns in pandas data frame
    # sharpe: Sharpe ratio
    # CAGR: Compound Annual Growth Rate
    x = df[s1]
    y = df[s2]
    
    # run regression (including Kalman Filter) to find hedge ratio and then create spread series
    df1 = pd.DataFrame({'y':y,'x':x})
    df1.index = pd.to_datetime(df1.index)
    state_means = KalmanFilterRegression(KalmanFilterAverage(x),KalmanFilterAverage(y))
    df1['hr'] = - state_means[:,0]
    df1['spread'] = df1.y + (df1.x * df1.hr)
    
    # calculate half life
    halflife = half_life(df1['spread'])
    
    # calculate z-score with window = half life period
    meanSpread = df1.spread.rolling(window=halflife).mean()
    stdSpread = df1.spread.rolling(window=halflife).std()
    df1['zScore'] = (df1.spread-meanSpread)/stdSpread
    
    ##############################################################
    
    # trading logic
    entryZscore = 2
    exitZscore = 0
    
    #set up num units long
    df1['long entry'] = ((df1.zScore < - entryZscore) & ( df1.zScore.shift(1) > - entryZscore))
    df1['long exit'] = ((df1.zScore > - exitZscore) & (df1.zScore.shift(1) < - exitZscore))
    df1['num units long'] = np.nan 
    df1.loc[df1['long entry'],'num units long'] = 1 
    df1.loc[df1['long exit'],'num units long'] = 0 
    df1['num units long'][0] = 0 
    df1['num units long'] = df1['num units long'].fillna(method='pad')
    
    #set up num units short 
    df1['short entry'] = ((df1.zScore > entryZscore) & ( df1.zScore.shift(1) < entryZscore))
    df1['short exit'] = ((df1.zScore < exitZscore) & (df1.zScore.shift(1) > exitZscore))
    df1.loc[df1['short entry'],'num units short'] = -1
    df1.loc[df1['short exit'],'num units short'] = 0
    df1['num units short'][0] = 0
    df1['num units short'] = df1['num units short'].fillna(method='pad')
    df1['numUnits'] = df1['num units long'] + df1['num units short']
    df1['spread pct ch'] = (df1['spread'] - df1['spread'].shift(1)) / ((df1['x'] * abs(df1['hr'])) + df1['y'])
    df1['port rets'] = df1['spread pct ch'] * df1['numUnits'].shift(1)
    df1['cum rets'] = df1['port rets'].cumsum()
    df1['cum rets'] = df1['cum rets'] + 1

    ##############################################################
    
    try:
        sharpe = ((df1['port rets'].mean() / df1['port rets'].std()) * sqrt(252))
    except ZeroDivisionError:
        sharpe = 0.0
        
    ##############################################################
    
    start_val = 1
    end_val = df1['cum rets'].iat[-1]
    start_date = df1.iloc[0].name
    end_date = df1.iloc[-1].name
    days = (end_date - start_date).days
    CAGR = (end_val / start_val) ** (252.0/days) - 1
    #CAGR = round(((float(end_val) / float(start_val)) ** (252.0/days)) - 1,4)
    df1[s1+ " "+s2] = df1['cum rets']
    return df1[s1+" "+s2], sharpe, CAGR

# %% [markdown]
# So now let’s run our full list of pairs through our Backtest function, and print out some results along the way, and finally after storing the equity curve for each pair,
# produce a chart that plots out each curve.

# %%
results = []
for pair in pairs:
    rets, sharpe,  CAGR = backtest(df[split:],pair[0],pair[1])
    if round(sharpe,2) > 1.29:
        results.append(rets)
        print("The pair {} and {} produced a Sharpe Ratio of {} and a CAGR of {}".format(pair[0],pair[1],round(sharpe,2),round(CAGR,4)))
        #print("The pair {} and {} produced a Sharpe Ratio of {} and a CAGR of {}".format(pair[0],pair[1],round(sharpe,2),round(CAGR,4)))
        rets.plot(figsize=(12,6),legend=True)
        plt.legend(bbox_to_anchor=(1.01, 1.1), loc='upper left', ncol=1)
        plt.grid(b=None, which=u'major', axis=u'both')
        plt.title('All Statistically Significant Binance USDT Denominated Altcoin Pairs Returns')
        plt.xlabel('Date')
        plt.ylabel('Pair Returns');
# Out:
# The pair ETHBTC and AMBBTC produced a Sharpe Ratio of 2.02 and a CAGR of 0.2288
# The pair LTCBTC and BQXBTC produced a Sharpe Ratio of 1.44 and a CAGR of 0.2971
# The pair LTCBTC and LINKBTC produced a Sharpe Ratio of 1.31 and a CAGR of 0.3416
# The pair LTCBTC and XRPBTC produced a Sharpe Ratio of 1.47 and a CAGR of 0.2918
# The pair LTCBTC and ENJBTC produced a Sharpe Ratio of 1.92 and a CAGR of 0.3129
# The pair LTCBTC and DLTBTC produced a Sharpe Ratio of 1.46 and a CAGR of 0.3001
# The pair GASBTC and VIBBTC produced a Sharpe Ratio of 1.52 and a CAGR of 0.1581
# The pair GASBTC and BCPTBTC produced a Sharpe Ratio of 1.42 and a CAGR of 0.3605
# The pair MCOBTC and RDNBTC produced a Sharpe Ratio of 1.75 and a CAGR of 0.3411
# The pair MCOBTC and TNTBTC produced a Sharpe Ratio of 1.5 and a CAGR of 0.4756
# The pair MCOBTC and FUELBTC produced a Sharpe Ratio of 1.68 and a CAGR of 0.617
# The pair WTCBTC and ENGBTC produced a Sharpe Ratio of 1.36 and a CAGR of 0.254
# The pair QTUMBTC and VIBBTC produced a Sharpe Ratio of 1.95 and a CAGR of 0.4397
# The pair QTUMBTC and KMDBTC produced a Sharpe Ratio of 1.38 and a CAGR of 0.2995
# The pair QTUMBTC and RDNBTC produced a Sharpe Ratio of 2.14 and a CAGR of 0.4658
# The pair QTUMBTC and BCDBTC produced a Sharpe Ratio of 1.31 and a CAGR of 0.5144
# The pair QTUMBTC and ADXBTC produced a Sharpe Ratio of 1.67 and a CAGR of 0.4217
# The pair OMGBTC and VIBBTC produced a Sharpe Ratio of 1.79 and a CAGR of 0.4567
# The pair ZRXBTC and MANABTC produced a Sharpe Ratio of 1.75 and a CAGR of 0.6111
# The pair STRATBTC and IOTABTC produced a Sharpe Ratio of 1.44 and a CAGR of 0.3752
# The pair STRATBTC and ADXBTC produced a Sharpe Ratio of 1.7 and a CAGR of 0.4816
# The pair BQXBTC and OAXBTC produced a Sharpe Ratio of 1.43 and a CAGR of 0.7779
# The pair IOTABTC and MTHBTC produced a Sharpe Ratio of 1.6 and a CAGR of 0.9272
# The pair XVGBTC and MTHBTC produced a Sharpe Ratio of 1.32 and a CAGR of 0.9444
# The pair ETCBTC and ZECBTC produced a Sharpe Ratio of 1.35 and a CAGR of 0.2089
# The pair ETCBTC and XZCBTC produced a Sharpe Ratio of 1.54 and a CAGR of 0.3075
# The pair ENGBTC and XZCBTC produced a Sharpe Ratio of 1.3 and a CAGR of 0.3756
# The pair ZECBTC and DLTBTC produced a Sharpe Ratio of 1.33 and a CAGR of 0.2514
# The pair ZECBTC and BCDBTC produced a Sharpe Ratio of 3.05 and a CAGR of 0.4792
# The pair BNTBTC and RDNBTC produced a Sharpe Ratio of 1.4 and a CAGR of 0.4244
# The pair OAXBTC and STORJBTC produced a Sharpe Ratio of 1.56 and a CAGR of 0.7156
# The pair OAXBTC and BCDBTC produced a Sharpe Ratio of 1.35 and a CAGR of 0.5275
# The pair BTGBTC and EVXBTC produced a Sharpe Ratio of 1.33 and a CAGR of 0.435
# The pair BTGBTC and ADXBTC produced a Sharpe Ratio of 1.61 and a CAGR of 0.1127
# The pair ARKBTC and STORJBTC produced a Sharpe Ratio of 1.58 and a CAGR of 0.6078
# The pair KMDBTC and RDNBTC produced a Sharpe Ratio of 2.23 and a CAGR of 0.6844
# The pair XMRBTC and BCDBTC produced a Sharpe Ratio of 2.9 and a CAGR of 0.696
# The pair ARNBTC and POEBTC produced a Sharpe Ratio of 1.31 and a CAGR of 0.5199
# The pair GVTBTC and DGDBTC produced a Sharpe Ratio of 1.54 and a CAGR of 0.5125
# The pair XZCBTC and BCDBTC produced a Sharpe Ratio of 2.11 and a CAGR of 0.549
# The pair XZCBTC and ADXBTC produced a Sharpe Ratio of 1.89 and a CAGR of 0.3116
# The pair BCDBTC and ADXBTC produced a Sharpe Ratio of 2.32 and a CAGR of 0.623

# %% [markdown]
# Now we run a few extra lines of code to combine, equally weight, and print our our final equity curve:

# %%
#concatenate together the individual equity curves into a single DataFrame
results_df = pd.concat(results,axis=1).dropna()

#equally weight each equity curve by dividing each by the number of pairs held in the DataFrame
results_df /= len(results_df.columns)

#sum up the equally weighted equity curves to get our final equity curve
final_res = results_df.sum(axis=1)

#plot the chart of our final equity curve
final_res.plot(label='Portfolio Value ($)',color='#50db14', figsize=(12,6))
plt.title('> 1.29 Sharpe Equallly Weighted Binance USDT Denominated Altcoin Pairs Trade Returns')
plt.grid(b=None, which=u'major', axis=u'both')
plt.xlabel('Date')
plt.ylabel('Returns ($)')
plt.legend();

# %%
num_coins = len(results_df.columns)
print('Number of Pairs =', num_coins)
# Out:
# Number of Pairs = 42

# %% [markdown]
# ### Underwater Plot

# %%
ffn.to_drawdown_series(final_res).plot(kind = 'area',alpha=.4,label='Drawdown',color='#ff3838',figsize=(12,6),grid=False)
plt.title('> 1.29 Sharpe Equallly Weighted Binance USDT Denominated Altcoin Pairs Trade Drawdowns')
plt.xlabel('Date')
plt.ylabel('Drawdown (%)')
plt.legend(loc='lower right');

# %% [markdown]
# ### Total Returns Performance

# %%
perf = final_res.calc_stats()
perf.display()
# Out:
# Stats for None from 2018-08-25 00:00:00 - 2019-09-29 00:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 82.68%              5.76  73.37%  -2.94%
#
# Annualized Returns:
# mtd    3m     6m      ytd     1y      3y      5y    10y    incep.
# -----  -----  ------  ------  ------  ------  ----  -----  --------
# 3.96%  9.83%  22.41%  46.63%  70.70%  73.37%  -     -      73.37%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  5.76     6.78       -
# mean    38.21%   57.25%     46.63%
# vol     6.63%    8.45%      -
# skew    1.44     -0.13      -
# kurt    10.81    -1.37      -
# best    3.15%    8.39%      46.63%
# worst   -1.94%   1.08%      46.63%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -2.94%  -0.34%      2.74
#
# Misc:
# ---------------  -------
# avg. up month    4.77%
# avg. down month  -
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------

# %% [markdown]
# ### Monthly Returns Performance

# %%
perf.display_monthly_returns()
# Out:
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec    YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
#   2018   0      0      0      0       0     0      0      0      7.22   6.71   1.34   7.45  24.59
#   2019   6.52   4.98   8.39   1.08    3.4   5.74   2.54   2.69   3.96   0      0      0     46.63

# %%
perf.stats
# Out:
# start                    2018-08-25 00:00:00
# end                      2019-09-29 00:00:00
# rf                                         0
# total_return                        0.826827
# cagr                                0.733654
# max_drawdown                      -0.0293851
# calmar                               24.9669
# mtd                                0.0396392
# three_month                        0.0982915
# six_month                           0.224063
# ytd                                 0.466329
# one_year                            0.706968
# three_year                          0.733654
# five_year                                NaN
# ten_year                                 NaN
# incep                               0.733654
# daily_sharpe                         5.76273
# daily_sortino                        13.6631
# daily_mean                          0.382093
# daily_vol                          0.0663041
# daily_skew                           1.43824
# daily_kurt                           10.8124
# best_day                           0.0314714
# worst_day                         -0.0194093
# monthly_sharpe                       6.77845
# monthly_sortino                          inf
# monthly_mean                        0.572469
# monthly_vol                        0.0844543
# monthly_skew                       -0.129112
# monthly_kurt                        -1.37216
# best_month                         0.0838987
# worst_month                        0.0108383
# yearly_sharpe                            NaN
# yearly_sortino                           NaN
# yearly_mean                         0.466329
# yearly_vol                               NaN
# yearly_skew                              NaN
# yearly_kurt                              NaN
# best_year                           0.466329
# worst_year                          0.466329
# avg_drawdown                     -0.00336197
# avg_drawdown_days                    2.73913
# avg_up_month                       0.0477058
# avg_down_month                           NaN
# win_year_perc                              1
# twelve_month_win_perc                      1
# dtype: object

# %% [markdown]
# The Sharpe Ratio is very good. Also take into consideration trading cost for crypto currency is very minimal but was not factored in these performance stats. The testing period was only from August 2018 until September 29th 2019 only looking at specific pairs returns when traded in the training period that was able to yield a greater than 1.29 sharpe ratio. Then creating an equal weight portfolio of those high yielding sharpe pairs to trade in the test period. Cummulative returns were almost 82% for about 1yr with little to no drawdown (fucking impressive).
