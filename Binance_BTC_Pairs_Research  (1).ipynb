# %% [markdown]
# ### CRYPTO MEAN REVERSION PAIRS TRADING WITH INCLUSION OF A KALMAN FILTER

# %% [markdown]
# In this notebook we are going look at the concept of building a trading strategy backtest based on mean reverting, co-integrated pairs of crypto currencies. So to restate the theory in in terms of US equities, stocks that are statistically co-integrated move in a way that means when their prices start to diverge by a certain amount (i.e. the spread between the 2 stocks prices increases), we would expect that divergence to
# eventually revert back to the mean. In this instance we would look to sell the outperforming stock,and buy the under performing stock in our expectance that the under performing stock would eventually “catch up” with the overpeforming stock and rise in price, or vice versa the overperforming stock would in time suffer from the same downward pressure of the underperforming stock and fall in relative value.
#
# Hence, pairs trading is a market neutral trading strategy enabling traders to profit from virtually any market conditions: Bull Market, Bear Market, or Sideways Market.
#
# So in our search for co-integrated Altcoins, economic theory would suggest that we are more likley to find pairs of that are driven by the same factors, if we search for pairs that are drawn from similar/the same blockchain & technology. After all, it is logical to expect
# 2 Altcoins with similar blockchain tech and use case could be considered similar products, to be at the mercy of the same general ups and downs of the volatile crypto market.

# %% [markdown]
# ### Kalman Filter

# %% [markdown]
# So what is a Kalman Filter? Well this site (http://www.bzarg.com/p/how-a-kalman-filter-works-in-pictures/) explains and states the following:
#
# You can use a Kalman filter in any place where you have uncertain information about some dynamic system, and you can make an educated guess about what the system is going to do next. Even if messy reality comes along and interferes with the clean motion you guessed about, the Kalman filter will often do a very good job of figuring out what actually happened. And it can take advantage of correlations between crazy phenomena that you maybe wouldn’t have thought to exploit!
#
# Kalman filters are ideal for systems which are continuously changing. They have the advantage that they are light on memory (they don’t need to keep any history other than the previous state), and they are very fast, making them well suited for real time problems and embedded systems.
#
# So lets start to import the relevant modules we will need for our strategy backtest:

# %%
from time import time
import numpy as np                  
import matplotlib.pyplot as plt   
import datetime as dt  
import pandas as pd
import math
import os.path
import time
import json
import requests
from bitmex import bitmex
from binance.client import Client
from datetime import timedelta, datetime
from dateutil import parser
from tqdm import tqdm_notebook 
import seaborn as sns
import matplotlib as mpl
mpl.style.use('seaborn')
import statsmodels.api as sm
from pykalman import KalmanFilter
from math import sqrt
import warnings
warnings.filterwarnings('ignore')
import ffn

# %%
### CONSTANTS
binsizes = {"1m": 1, "5m": 5, "1h": 60, "4h": 240, "8h": 480, "12h": 720, "1d": 1440}
batch_size = 750
binance_client = Client(api_key=binance_api_key, api_secret=binance_api_secret)

# %%
### FUNCTIONS
def minutes_of_new_data(symbol, kline_size, data, source):
    if len(data) > 0:  old = parser.parse(data["timestamp"].iloc[-1])
    elif source == "binance": old = datetime.strptime('30 Nov 2017', '%d %b %Y')
    if source == "binance": new = pd.to_datetime(binance_client.get_klines(symbol=symbol, interval=kline_size)[-1][0], unit='ms')
    return old, new

## Get Historical Pricing from Binance 
def get_all_binance(symbol, kline_size, save = False):
    filename = 'Binance_%s_%s_data.csv' % (symbol, kline_size)
    if os.path.isfile(filename): data_df = pd.read_csv(filename)
    else: data_df = pd.DataFrame()
    oldest_point, newest_point = minutes_of_new_data(symbol, kline_size, data_df, source = "binance")
    delta_min = (newest_point - oldest_point).total_seconds()/60
    available_data = math.ceil(delta_min/binsizes[kline_size])
    if oldest_point == datetime.strptime('30 Nov 2017', '%d %b %Y'): print('Downloading all available %s data for %s. Be patient..!' % (kline_size, symbol))
    else: print('Downloading %d minutes of new data available for %s, i.e. %d instances of %s data.' % (delta_min, symbol, available_data, kline_size))
    klines = binance_client.get_historical_klines(symbol, kline_size, oldest_point.strftime("%d %b %Y %H:%M:%S"), newest_point.strftime("%d %b %Y %H:%M:%S"))
    data = pd.DataFrame(klines, columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av', 'ignore' ])
    data = data.drop('ignore', axis=1)
    data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')
    if len(data_df) > 0:
        temp_df = pd.DataFrame(data)
        data_df = data_df.append(temp_df)
    else: data_df = data
    data_df.set_index('timestamp', inplace=True)
    print('All caught up..!')
    return data_df

# %%
# For all Binance USDT symbols
# https://steemit.com/money/@marketstack/visualizing-alt-coin-correlation
symbols = json.loads(requests.get("https://api.binance.com/api/v1/exchangeInfo").text)
symbols = [symbol['symbol'] for symbol in symbols['symbols'] if symbol['quoteAsset'] == 'BTC']

# %% [markdown]
# What we're left with here is a list of any pair with BTC as the quote side of the pair. We will combine this data with the price history of BTC/USDT to create time series for each cryptocurrency quoted in USDT instead of BTC.
#
# To do this we'll use our get_bars function to retrieve the data for BTC/USDT

# %%
btcusdt = get_all_binance('BTCUSDT', '8h', save = False)
# Out:
# Downloading all available 8h data for BTCUSDT. Be patient..!
# All caught up..!

# %%
# Downloading all Altcoin price data
price_data = []
new_symbols = []
binance_symbols = symbols
for symbol in binance_symbols:
    data = get_all_binance(symbol, '8h', save = False)
    new_symbols.append(symbol.replace('BTC','USDT')) 
    price_data.append(data['close'].astype('float') * btcusdt['close'].astype('float'))
# Out:
# Downloading all available 8h data for ETHBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LTCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BNBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NEOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GASBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for HSRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MCOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WTCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LRCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for QTUMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for YOYOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for OMGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ZRXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for STRATBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SNGLSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BQXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for KNCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for FUNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SNMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for IOTABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LINKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XVGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SALTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MDABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MTLBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SUBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for EOSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SNTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ETCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MTHBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ENGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DNTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ZECBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BNTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ASTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DASHBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for OAXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ICNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BTGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for EVXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for REQBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for VIBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TRXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for POWRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ARKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XRPBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MODBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ENJBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for STORJBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for VENBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for KMDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RCNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NULSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RDNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XMRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DLTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for AMBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BATBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCPTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ARNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GVTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CDTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GXSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for POEBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for QSPBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BTSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XZCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LSKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TNTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for FUELBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MANABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DGDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ADXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ADABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PPTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CMTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XLMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CNDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LENDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WABIBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TNBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WAVESBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GTOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ICXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for OSTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ELFBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for AIONBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NEBLBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BRDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for EDOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WINGSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NAVBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LUNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TRIGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for APPCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for VIBEBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RLCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for INSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PIVXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for IOSTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CHATBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for STEEMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NANOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for VIABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BLZBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for AEBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RPXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NCASHBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for POABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ZILBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ONTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for STORMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XEMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WANBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WPRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for QLCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SYSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GRSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CLOAKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GNTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for LOOMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for REPBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TUSDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ZENBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SKYBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CVCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for THETABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for IOTXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for QKCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for AGIBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NXSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DATABTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for SCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NPXSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for KEYBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for NASBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MFTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DENTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ARDRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for HOTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for VETBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DOCKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for POLYBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PHXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for HCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for GOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PAXBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RVNBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DCRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MITHBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCHABCBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BCHSVBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for RENBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BTTBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ONGBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for FETBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CELRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for MATICBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ATOMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PHBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TFUELBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ONEBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for FTMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BTCBBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ALGOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ERDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DOGEBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for DUSKBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for ANKRBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for WINBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for COSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for COCOSBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for TOMOBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for PERLBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for CHZBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BANDBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for BEAMBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for XTZBTC. Be patient..!
# All caught up..!
# Downloading all available 8h data for HBARBTC. Be patient..!
# All caught up..!

# %%
# Merge all price data into a single dataframe and drop all NaNs
combo = pd.concat(price_data, axis = 1)
combo.columns = new_symbols
combo = combo.dropna(axis=1, how='any', thresh=None, subset=None, inplace=False)
combo.head()
# Out:
#                         ETHUSDT    LTCUSDT   BNBUSDT    NEOUSDT    GASUSDT  \
# timestamp
# 2017-11-30 00:00:00  434.298960  85.967590  1.879968  32.757710  19.193420
# 2017-11-30 08:00:00  392.219460  75.153620  1.785134  29.400520  16.451360
# 2017-11-30 16:00:00  429.480443  85.412012  1.967792  32.557119  18.595634
# 2017-12-01 00:00:00  419.387940  82.358820  1.962092  33.962400  18.469440
# 2017-12-01 08:00:00  446.401420  91.211200  2.030391  34.905020  18.838460
#
#                       MCOUSDT   WTCUSDT   LRCUSDT   QTUMUSDT  YOYOUSDT  \
# timestamp
# 2017-11-30 00:00:00  5.961440  5.186654  0.193646  12.053790  0.073511
# 2017-11-30 08:00:00  5.037780  5.001860  0.169722  10.946620  0.071840
# 2017-11-30 16:00:00  5.696758  6.670421  0.203273  11.875625  0.087567
# 2017-12-01 00:00:00  5.609520  6.410594  0.208449  11.495700  0.089962
# 2017-12-01 08:00:00  5.993580  7.149724  0.210664  12.196360  0.092676
#
#                        ...      QSPUSDT   BTSUSDT    XZCUSDT   LSKUSDT  \
# timestamp              ...
# 2017-11-30 00:00:00    ...     0.118020  0.136046  35.970040  7.153728
# 2017-11-30 08:00:00    ...     0.097972  0.119434  31.573680  6.555400
# 2017-11-30 16:00:00    ...     0.118166  0.131645  35.420256  7.408737
# 2017-12-01 00:00:00    ...     0.108565  0.131652  34.906860  7.216056
# 2017-12-01 08:00:00    ...     0.118616  0.140164  37.300360  7.638938
#
#                       TNTUSDT  FUELUSDT  MANAUSDT   BCDUSDT     DGDUSDT  \
# timestamp
# 2017-11-30 00:00:00  0.073712  0.037763  0.015508  51.77994  117.738440
# 2017-11-30 08:00:00  0.066991  0.037267  0.013380  47.59400   87.869300
# 2017-11-30 16:00:00  0.073202  0.038470  0.015152  50.61161   98.556862
# 2017-12-01 00:00:00  0.073076  0.040068  0.014501  49.53168   96.287220
# 2017-12-01 08:00:00  0.076149  0.042572  0.015481  54.82086  102.738120
#
#                       ADXUSDT
# timestamp
# 2017-11-30 00:00:00  1.095817
# 2017-11-30 08:00:00  0.978820
# 2017-11-30 16:00:00  1.082384
# 2017-12-01 00:00:00  1.066667
# 2017-12-01 08:00:00  1.202795
#
# [5 rows x 68 columns]

# %% [markdown]
# Plot the resulting DataFrame of price data just to make sure we have what we need and as a quick sanity check:

# %%
num_coins = len(combo.columns)
print('Number of Altcoins =', num_coins)
# Out:
# Number of Altcoins = 68

# %%
combo.div(combo.iloc[0,:]).plot(figsize=(12, 6))# Normalize Prices 
plt.title('ALL Binance USDT Denominated Altcoins Normalized Price Series')
plt.xlabel('Date')
plt.ylabel('Price ($USDT)')
plt.grid(b=None, which=u'major', axis=u'both')
plt.legend(bbox_to_anchor=(1.01, 1.1), loc='upper left', ncol=1)
plt.show();

# %% [markdown]
# Ok so it looks from the chart as if we have around price data downloaded for 69 Altcoins; this should be more than enough to find at least a couple of co-integrated pairs to run our backtest over.
#
# We will now define a quick function that will run our Altcoins, combining them into pairs one by one and running co-integration tests on each pair. That result will then be stored in a matrix that we initialise,
# and then we will be able to plot that matrix as a heatmap. Also, if the co-integration test meets our threshold statistical significance (in our case 5%), then that pair of Altcoin tickers will be stored in a list for later retrieval.

# %%
# Source: https://pythonforfinance.net/2018/07/04/mean-reversion-pairs-trading-with-inclusion-of-a-kalman-filter/
# NOTE CRITICAL LEVEL HAS BEEN SET TO 5% FOR COINTEGRATION TEST
def find_cointegrated_pairs(dataframe, critial_level = 0.05):
    n = dataframe.shape[1] # the length of dateframe
    pvalue_matrix = np.ones((n, n)) # initialize the matrix of p
    keys = dataframe.columns # get the column names
    pairs = [] # initilize the list for cointegration
    for i in range(n):
        for j in range(i+1, n): # for j bigger than i
            stock1 = dataframe[keys[i]] # obtain the price of "stock1"
            stock2 = dataframe[keys[j]]# obtain the price of "stock2"
            result = sm.tsa.stattools.coint(stock1, stock2) # get conintegration
            pvalue = result[1] # get the pvalue
            pvalue_matrix[i, j] = pvalue
            if pvalue < critial_level: # if p-value less than the critical level
                pairs.append((keys[i], keys[j], pvalue)) # record the contract with that p-value
    return pvalue_matrix, pairs

# %% [markdown]
# Let’s now run our data through our function, save the results and plot the heatmap:

# %%
df = combo

binance_symbols = df.columns

# Set up the split point for our "training data" on which to perform the co-integration test (the remaining dat awill be fed to our backtest function)
split = int(len(df) * 0.4)

# Run our dataframe (up to the split point) of ticker price data through our co-integration function and store results
pvalue_matrix,pairs = find_cointegrated_pairs(df[:split])

# Convert our matrix of stored results into a DataFrame
pvalue_matrix_df = pd.DataFrame(pvalue_matrix)

# Use Seaborn to plot a heatmap of our results matrix
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(pvalue_matrix_df,xticklabels=binance_symbols,yticklabels=binance_symbols,ax=ax,cmap="RdYlGn")
plt.title('Binance Altcoin P-value Matrix')
plt.show();

# %% [markdown]
# So we can see from the very dark red squares that it looks as though there are indeed a few pairs of Altcoins who’s co-integration score is below the 5% threshold
# hardcoded into the function we defined. To see more explicitly which pairs these are, let’s print out our list of stored pairs that was part of the fucntion results we stored:

# %%
for pair in pairs:
    print("Altcoin {} and Altcoin {} has a co-integration score of {}".format(pair[0],pair[1],round(pair[2],4)))
# Out:
# Altcoin ETHUSDT and Altcoin GASUSDT has a co-integration score of 0.0073
# Altcoin ETHUSDT and Altcoin WTCUSDT has a co-integration score of 0.039
# Altcoin ETHUSDT and Altcoin BQXUSDT has a co-integration score of 0.0039
# Altcoin ETHUSDT and Altcoin FUNUSDT has a co-integration score of 0.0496
# Altcoin ETHUSDT and Altcoin OAXUSDT has a co-integration score of 0.0179
# Altcoin ETHUSDT and Altcoin EVXUSDT has a co-integration score of 0.0427
# Altcoin ETHUSDT and Altcoin CDTUSDT has a co-integration score of 0.0387
# Altcoin ETHUSDT and Altcoin GXSUSDT has a co-integration score of 0.0066
# Altcoin ETHUSDT and Altcoin POEUSDT has a co-integration score of 0.0025
# Altcoin ETHUSDT and Altcoin QSPUSDT has a co-integration score of 0.0024
# Altcoin ETHUSDT and Altcoin XZCUSDT has a co-integration score of 0.0064
# Altcoin ETHUSDT and Altcoin LSKUSDT has a co-integration score of 0.0276
# Altcoin ETHUSDT and Altcoin TNTUSDT has a co-integration score of 0.0364
# Altcoin ETHUSDT and Altcoin FUELUSDT has a co-integration score of 0.0248
# Altcoin ETHUSDT and Altcoin BCDUSDT has a co-integration score of 0.0119
# Altcoin ETHUSDT and Altcoin ADXUSDT has a co-integration score of 0.0184
# Altcoin LTCUSDT and Altcoin YOYOUSDT has a co-integration score of 0.0287
# Altcoin LTCUSDT and Altcoin STRATUSDT has a co-integration score of 0.0019
# Altcoin LTCUSDT and Altcoin SNGLSUSDT has a co-integration score of 0.0037
# Altcoin LTCUSDT and Altcoin IOTAUSDT has a co-integration score of 0.0132
# Altcoin LTCUSDT and Altcoin MDAUSDT has a co-integration score of 0.0219
# Altcoin LTCUSDT and Altcoin MTLUSDT has a co-integration score of 0.0
# Altcoin LTCUSDT and Altcoin ETCUSDT has a co-integration score of 0.0098
# Altcoin LTCUSDT and Altcoin MTHUSDT has a co-integration score of 0.0339
# Altcoin LTCUSDT and Altcoin ZECUSDT has a co-integration score of 0.0104
# Altcoin LTCUSDT and Altcoin DASHUSDT has a co-integration score of 0.0002
# Altcoin LTCUSDT and Altcoin OAXUSDT has a co-integration score of 0.0273
# Altcoin LTCUSDT and Altcoin BTGUSDT has a co-integration score of 0.0002
# Altcoin LTCUSDT and Altcoin VIBUSDT has a co-integration score of 0.0174
# Altcoin LTCUSDT and Altcoin POWRUSDT has a co-integration score of 0.0372
# Altcoin LTCUSDT and Altcoin ARKUSDT has a co-integration score of 0.0057
# Altcoin LTCUSDT and Altcoin STORJUSDT has a co-integration score of 0.0112
# Altcoin LTCUSDT and Altcoin KMDUSDT has a co-integration score of 0.017
# Altcoin LTCUSDT and Altcoin RCNUSDT has a co-integration score of 0.0035
# Altcoin LTCUSDT and Altcoin RDNUSDT has a co-integration score of 0.0285
# Altcoin LTCUSDT and Altcoin XMRUSDT has a co-integration score of 0.0
# Altcoin LTCUSDT and Altcoin XZCUSDT has a co-integration score of 0.0
# Altcoin LTCUSDT and Altcoin LSKUSDT has a co-integration score of 0.0486
# Altcoin LTCUSDT and Altcoin FUELUSDT has a co-integration score of 0.041
# Altcoin LTCUSDT and Altcoin BCDUSDT has a co-integration score of 0.0017
# Altcoin LTCUSDT and Altcoin ADXUSDT has a co-integration score of 0.0003
# Altcoin BNBUSDT and Altcoin ETCUSDT has a co-integration score of 0.0471
# Altcoin NEOUSDT and Altcoin WTCUSDT has a co-integration score of 0.0038
# Altcoin NEOUSDT and Altcoin OAXUSDT has a co-integration score of 0.0306
# Altcoin NEOUSDT and Altcoin BCPTUSDT has a co-integration score of 0.0129
# Altcoin NEOUSDT and Altcoin ARNUSDT has a co-integration score of 0.0435
# Altcoin NEOUSDT and Altcoin POEUSDT has a co-integration score of 0.0487
# Altcoin NEOUSDT and Altcoin QSPUSDT has a co-integration score of 0.0359
# Altcoin NEOUSDT and Altcoin LSKUSDT has a co-integration score of 0.0106
# Altcoin GASUSDT and Altcoin BQXUSDT has a co-integration score of 0.0017
# Altcoin GASUSDT and Altcoin KNCUSDT has a co-integration score of 0.0126
# Altcoin GASUSDT and Altcoin BNTUSDT has a co-integration score of 0.0115
# Altcoin GASUSDT and Altcoin OAXUSDT has a co-integration score of 0.0104
# Altcoin GASUSDT and Altcoin EVXUSDT has a co-integration score of 0.0047
# Altcoin GASUSDT and Altcoin REQUSDT has a co-integration score of 0.0263
# Altcoin GASUSDT and Altcoin ENJUSDT has a co-integration score of 0.0243
# Altcoin GASUSDT and Altcoin AMBUSDT has a co-integration score of 0.0126
# Altcoin GASUSDT and Altcoin BCPTUSDT has a co-integration score of 0.0282
# Altcoin GASUSDT and Altcoin POEUSDT has a co-integration score of 0.0047
# Altcoin GASUSDT and Altcoin QSPUSDT has a co-integration score of 0.0007
# Altcoin GASUSDT and Altcoin LSKUSDT has a co-integration score of 0.0015
# Altcoin GASUSDT and Altcoin TNTUSDT has a co-integration score of 0.0012
# Altcoin GASUSDT and Altcoin BCDUSDT has a co-integration score of 0.0334
# Altcoin MCOUSDT and Altcoin QTUMUSDT has a co-integration score of 0.0329
# Altcoin MCOUSDT and Altcoin YOYOUSDT has a co-integration score of 0.0
# Altcoin MCOUSDT and Altcoin IOTAUSDT has a co-integration score of 0.0023
# Altcoin MCOUSDT and Altcoin XVGUSDT has a co-integration score of 0.031
# Altcoin MCOUSDT and Altcoin MDAUSDT has a co-integration score of 0.0051
# Altcoin MCOUSDT and Altcoin MTLUSDT has a co-integration score of 0.0214
# Altcoin MCOUSDT and Altcoin ZECUSDT has a co-integration score of 0.0408
# Altcoin MCOUSDT and Altcoin DASHUSDT has a co-integration score of 0.0012
# Altcoin MCOUSDT and Altcoin BTGUSDT has a co-integration score of 0.0008
# Altcoin MCOUSDT and Altcoin POWRUSDT has a co-integration score of 0.0265
# Altcoin MCOUSDT and Altcoin ARKUSDT has a co-integration score of 0.0096
# Altcoin MCOUSDT and Altcoin STORJUSDT has a co-integration score of 0.0144
# Altcoin MCOUSDT and Altcoin KMDUSDT has a co-integration score of 0.0115
# Altcoin MCOUSDT and Altcoin RDNUSDT has a co-integration score of 0.0381
# Altcoin MCOUSDT and Altcoin GXSUSDT has a co-integration score of 0.0385
# Altcoin MCOUSDT and Altcoin BTSUSDT has a co-integration score of 0.0099
# Altcoin WTCUSDT and Altcoin ASTUSDT has a co-integration score of 0.0378
# Altcoin LRCUSDT and Altcoin BQXUSDT has a co-integration score of 0.0247
# Altcoin LRCUSDT and Altcoin AMBUSDT has a co-integration score of 0.0047
# Altcoin LRCUSDT and Altcoin POEUSDT has a co-integration score of 0.0422
# Altcoin LRCUSDT and Altcoin QSPUSDT has a co-integration score of 0.0324
# Altcoin LRCUSDT and Altcoin BCDUSDT has a co-integration score of 0.0243
# Altcoin QTUMUSDT and Altcoin STRATUSDT has a co-integration score of 0.0016
# Altcoin QTUMUSDT and Altcoin SNGLSUSDT has a co-integration score of 0.0033
# Altcoin QTUMUSDT and Altcoin FUNUSDT has a co-integration score of 0.0348
# Altcoin QTUMUSDT and Altcoin MDAUSDT has a co-integration score of 0.0085
# Altcoin QTUMUSDT and Altcoin SNTUSDT has a co-integration score of 0.0195
# Altcoin QTUMUSDT and Altcoin MTHUSDT has a co-integration score of 0.0291
# Altcoin QTUMUSDT and Altcoin ZECUSDT has a co-integration score of 0.0071
# Altcoin QTUMUSDT and Altcoin DASHUSDT has a co-integration score of 0.0154
# Altcoin QTUMUSDT and Altcoin OAXUSDT has a co-integration score of 0.0475
# Altcoin QTUMUSDT and Altcoin BTGUSDT has a co-integration score of 0.0165
# Altcoin QTUMUSDT and Altcoin REQUSDT has a co-integration score of 0.0113
# Altcoin QTUMUSDT and Altcoin VIBUSDT has a co-integration score of 0.0007
# Altcoin QTUMUSDT and Altcoin POWRUSDT has a co-integration score of 0.0029
# Altcoin QTUMUSDT and Altcoin ARKUSDT has a co-integration score of 0.0006
# Altcoin QTUMUSDT and Altcoin XRPUSDT has a co-integration score of 0.0302
# Altcoin QTUMUSDT and Altcoin STORJUSDT has a co-integration score of 0.0037
# Altcoin QTUMUSDT and Altcoin KMDUSDT has a co-integration score of 0.0
# Altcoin QTUMUSDT and Altcoin RCNUSDT has a co-integration score of 0.0003
# Altcoin QTUMUSDT and Altcoin RDNUSDT has a co-integration score of 0.0004
# Altcoin QTUMUSDT and Altcoin CDTUSDT has a co-integration score of 0.0004
# Altcoin QTUMUSDT and Altcoin XZCUSDT has a co-integration score of 0.0
# Altcoin QTUMUSDT and Altcoin TNTUSDT has a co-integration score of 0.0062
# Altcoin QTUMUSDT and Altcoin BCDUSDT has a co-integration score of 0.0012
# Altcoin QTUMUSDT and Altcoin ADXUSDT has a co-integration score of 0.0001
# Altcoin YOYOUSDT and Altcoin STRATUSDT has a co-integration score of 0.0119
# Altcoin YOYOUSDT and Altcoin FUNUSDT has a co-integration score of 0.0304
# Altcoin YOYOUSDT and Altcoin IOTAUSDT has a co-integration score of 0.0035
# Altcoin YOYOUSDT and Altcoin XVGUSDT has a co-integration score of 0.0209
# Altcoin YOYOUSDT and Altcoin MTLUSDT has a co-integration score of 0.0186
# Altcoin YOYOUSDT and Altcoin ZECUSDT has a co-integration score of 0.0381
# Altcoin YOYOUSDT and Altcoin DASHUSDT has a co-integration score of 0.0
# Altcoin YOYOUSDT and Altcoin BTGUSDT has a co-integration score of 0.0
# Altcoin YOYOUSDT and Altcoin ARKUSDT has a co-integration score of 0.0126
# Altcoin YOYOUSDT and Altcoin STORJUSDT has a co-integration score of 0.0481
# Altcoin YOYOUSDT and Altcoin KMDUSDT has a co-integration score of 0.0042
# Altcoin YOYOUSDT and Altcoin RCNUSDT has a co-integration score of 0.0192
# Altcoin YOYOUSDT and Altcoin GXSUSDT has a co-integration score of 0.012
# Altcoin YOYOUSDT and Altcoin XZCUSDT has a co-integration score of 0.0044
# Altcoin YOYOUSDT and Altcoin BCDUSDT has a co-integration score of 0.0016
# Altcoin YOYOUSDT and Altcoin ADXUSDT has a co-integration score of 0.0133
# Altcoin OMGUSDT and Altcoin BQXUSDT has a co-integration score of 0.0409
# Altcoin OMGUSDT and Altcoin BCPTUSDT has a co-integration score of 0.0042
# Altcoin ZRXUSDT and Altcoin MANAUSDT has a co-integration score of 0.0378
# Altcoin STRATUSDT and Altcoin SNGLSUSDT has a co-integration score of 0.0001
# Altcoin STRATUSDT and Altcoin XVGUSDT has a co-integration score of 0.0216
# Altcoin STRATUSDT and Altcoin MDAUSDT has a co-integration score of 0.0021
# Altcoin STRATUSDT and Altcoin ZECUSDT has a co-integration score of 0.0006
# Altcoin STRATUSDT and Altcoin REQUSDT has a co-integration score of 0.0004
# Altcoin STRATUSDT and Altcoin VIBUSDT has a co-integration score of 0.0077
# Altcoin STRATUSDT and Altcoin POWRUSDT has a co-integration score of 0.0
# Altcoin STRATUSDT and Altcoin ARKUSDT has a co-integration score of 0.0005
# Altcoin STRATUSDT and Altcoin XRPUSDT has a co-integration score of 0.013
# Altcoin STRATUSDT and Altcoin STORJUSDT has a co-integration score of 0.0038
# Altcoin STRATUSDT and Altcoin KMDUSDT has a co-integration score of 0.0254
# Altcoin STRATUSDT and Altcoin RCNUSDT has a co-integration score of 0.0035
# Altcoin STRATUSDT and Altcoin RDNUSDT has a co-integration score of 0.0
# Altcoin STRATUSDT and Altcoin CDTUSDT has a co-integration score of 0.0
# Altcoin STRATUSDT and Altcoin GXSUSDT has a co-integration score of 0.0276
# Altcoin STRATUSDT and Altcoin BTSUSDT has a co-integration score of 0.0405
# Altcoin STRATUSDT and Altcoin XZCUSDT has a co-integration score of 0.0012
# Altcoin STRATUSDT and Altcoin TNTUSDT has a co-integration score of 0.0006
# Altcoin STRATUSDT and Altcoin BCDUSDT has a co-integration score of 0.0246
# Altcoin STRATUSDT and Altcoin ADXUSDT has a co-integration score of 0.0079
# Altcoin SNGLSUSDT and Altcoin KNCUSDT has a co-integration score of 0.0281
# Altcoin SNGLSUSDT and Altcoin FUNUSDT has a co-integration score of 0.0306
# Altcoin SNGLSUSDT and Altcoin XVGUSDT has a co-integration score of 0.0277
# Altcoin SNGLSUSDT and Altcoin SNTUSDT has a co-integration score of 0.0281
# Altcoin SNGLSUSDT and Altcoin MTHUSDT has a co-integration score of 0.0025
# Altcoin SNGLSUSDT and Altcoin ZECUSDT has a co-integration score of 0.0177
# Altcoin SNGLSUSDT and Altcoin REQUSDT has a co-integration score of 0.0028
# Altcoin SNGLSUSDT and Altcoin VIBUSDT has a co-integration score of 0.0092
# Altcoin SNGLSUSDT and Altcoin POWRUSDT has a co-integration score of 0.0009
# Altcoin SNGLSUSDT and Altcoin ARKUSDT has a co-integration score of 0.0359
# Altcoin SNGLSUSDT and Altcoin XRPUSDT has a co-integration score of 0.0478
# Altcoin SNGLSUSDT and Altcoin ENJUSDT has a co-integration score of 0.0478
# Altcoin SNGLSUSDT and Altcoin KMDUSDT has a co-integration score of 0.0058
# Altcoin SNGLSUSDT and Altcoin RCNUSDT has a co-integration score of 0.0004
# Altcoin SNGLSUSDT and Altcoin RDNUSDT has a co-integration score of 0.005
# Altcoin SNGLSUSDT and Altcoin CDTUSDT has a co-integration score of 0.0005
# Altcoin SNGLSUSDT and Altcoin GXSUSDT has a co-integration score of 0.0074
# Altcoin SNGLSUSDT and Altcoin BTSUSDT has a co-integration score of 0.0321
# Altcoin SNGLSUSDT and Altcoin XZCUSDT has a co-integration score of 0.004
# Altcoin SNGLSUSDT and Altcoin TNTUSDT has a co-integration score of 0.0084
# Altcoin SNGLSUSDT and Altcoin BCDUSDT has a co-integration score of 0.0004
# Altcoin SNGLSUSDT and Altcoin ADXUSDT has a co-integration score of 0.0055
# Altcoin BQXUSDT and Altcoin KNCUSDT has a co-integration score of 0.0064
# Altcoin BQXUSDT and Altcoin XVGUSDT has a co-integration score of 0.0205
# Altcoin BQXUSDT and Altcoin SNTUSDT has a co-integration score of 0.014
# Altcoin BQXUSDT and Altcoin ENGUSDT has a co-integration score of 0.0088
# Altcoin BQXUSDT and Altcoin BNTUSDT has a co-integration score of 0.0005
# Altcoin BQXUSDT and Altcoin ASTUSDT has a co-integration score of 0.0366
# Altcoin BQXUSDT and Altcoin OAXUSDT has a co-integration score of 0.0
# Altcoin BQXUSDT and Altcoin EVXUSDT has a co-integration score of 0.0076
# Altcoin BQXUSDT and Altcoin REQUSDT has a co-integration score of 0.0233
# Altcoin BQXUSDT and Altcoin VIBUSDT has a co-integration score of 0.0121
# Altcoin BQXUSDT and Altcoin ARKUSDT has a co-integration score of 0.0463
# Altcoin BQXUSDT and Altcoin ENJUSDT has a co-integration score of 0.0
# Altcoin BQXUSDT and Altcoin STORJUSDT has a co-integration score of 0.0494
# Altcoin BQXUSDT and Altcoin RCNUSDT has a co-integration score of 0.0118
# Altcoin BQXUSDT and Altcoin RDNUSDT has a co-integration score of 0.0248
# Altcoin BQXUSDT and Altcoin XMRUSDT has a co-integration score of 0.0177
# Altcoin BQXUSDT and Altcoin DLTUSDT has a co-integration score of 0.0063
# Altcoin BQXUSDT and Altcoin AMBUSDT has a co-integration score of 0.0134
# Altcoin BQXUSDT and Altcoin POEUSDT has a co-integration score of 0.0026
# Altcoin BQXUSDT and Altcoin QSPUSDT has a co-integration score of 0.0004
# Altcoin BQXUSDT and Altcoin XZCUSDT has a co-integration score of 0.0161
# Altcoin BQXUSDT and Altcoin LSKUSDT has a co-integration score of 0.008
# Altcoin BQXUSDT and Altcoin TNTUSDT has a co-integration score of 0.0025
# Altcoin BQXUSDT and Altcoin FUELUSDT has a co-integration score of 0.0374
# Altcoin BQXUSDT and Altcoin BCDUSDT has a co-integration score of 0.0018
# Altcoin BQXUSDT and Altcoin ADXUSDT has a co-integration score of 0.0165
# Altcoin KNCUSDT and Altcoin ASTUSDT has a co-integration score of 0.0409
# Altcoin KNCUSDT and Altcoin VIBUSDT has a co-integration score of 0.0246
# Altcoin KNCUSDT and Altcoin RDNUSDT has a co-integration score of 0.0207
# Altcoin KNCUSDT and Altcoin AMBUSDT has a co-integration score of 0.0119
# Altcoin KNCUSDT and Altcoin POEUSDT has a co-integration score of 0.0129
# Altcoin KNCUSDT and Altcoin QSPUSDT has a co-integration score of 0.0026
# Altcoin KNCUSDT and Altcoin XZCUSDT has a co-integration score of 0.0443
# Altcoin KNCUSDT and Altcoin TNTUSDT has a co-integration score of 0.0006
# Altcoin KNCUSDT and Altcoin BCDUSDT has a co-integration score of 0.0116
# Altcoin FUNUSDT and Altcoin IOTAUSDT has a co-integration score of 0.0051
# Altcoin FUNUSDT and Altcoin XVGUSDT has a co-integration score of 0.0074
# Altcoin FUNUSDT and Altcoin SNTUSDT has a co-integration score of 0.0015
# Altcoin FUNUSDT and Altcoin MTHUSDT has a co-integration score of 0.0
# Altcoin FUNUSDT and Altcoin ZECUSDT has a co-integration score of 0.0271
# Altcoin FUNUSDT and Altcoin BNTUSDT has a co-integration score of 0.0492
# Altcoin FUNUSDT and Altcoin ASTUSDT has a co-integration score of 0.0003
# Altcoin FUNUSDT and Altcoin BTGUSDT has a co-integration score of 0.0333
# Altcoin FUNUSDT and Altcoin EVXUSDT has a co-integration score of 0.0218
# Altcoin FUNUSDT and Altcoin REQUSDT has a co-integration score of 0.001
# Altcoin FUNUSDT and Altcoin VIBUSDT has a co-integration score of 0.0008
# Altcoin FUNUSDT and Altcoin POWRUSDT has a co-integration score of 0.0117
# Altcoin FUNUSDT and Altcoin ARKUSDT has a co-integration score of 0.0036
# Altcoin FUNUSDT and Altcoin XRPUSDT has a co-integration score of 0.0007
# Altcoin FUNUSDT and Altcoin STORJUSDT has a co-integration score of 0.0452
# Altcoin FUNUSDT and Altcoin KMDUSDT has a co-integration score of 0.0081
# Altcoin FUNUSDT and Altcoin RCNUSDT has a co-integration score of 0.0019
# Altcoin FUNUSDT and Altcoin RDNUSDT has a co-integration score of 0.0071
# Altcoin FUNUSDT and Altcoin DLTUSDT has a co-integration score of 0.0001
# Altcoin FUNUSDT and Altcoin POEUSDT has a co-integration score of 0.039
# Altcoin FUNUSDT and Altcoin XZCUSDT has a co-integration score of 0.0005
# Altcoin FUNUSDT and Altcoin LSKUSDT has a co-integration score of 0.0312
# Altcoin FUNUSDT and Altcoin TNTUSDT has a co-integration score of 0.0076
# Altcoin FUNUSDT and Altcoin FUELUSDT has a co-integration score of 0.0049
# Altcoin FUNUSDT and Altcoin BCDUSDT has a co-integration score of 0.0006
# Altcoin FUNUSDT and Altcoin ADXUSDT has a co-integration score of 0.001
# Altcoin SNMUSDT and Altcoin VIBUSDT has a co-integration score of 0.0221
# Altcoin SNMUSDT and Altcoin ARKUSDT has a co-integration score of 0.0482
# Altcoin SNMUSDT and Altcoin XRPUSDT has a co-integration score of 0.0166
# Altcoin SNMUSDT and Altcoin STORJUSDT has a co-integration score of 0.0099
# Altcoin SNMUSDT and Altcoin RCNUSDT has a co-integration score of 0.0045
# Altcoin SNMUSDT and Altcoin CDTUSDT has a co-integration score of 0.0394
# Altcoin SNMUSDT and Altcoin XZCUSDT has a co-integration score of 0.023
# Altcoin SNMUSDT and Altcoin TNTUSDT has a co-integration score of 0.0278
# Altcoin SNMUSDT and Altcoin BCDUSDT has a co-integration score of 0.0035
# Altcoin SNMUSDT and Altcoin ADXUSDT has a co-integration score of 0.0199
# Altcoin IOTAUSDT and Altcoin XVGUSDT has a co-integration score of 0.0311
# Altcoin IOTAUSDT and Altcoin MDAUSDT has a co-integration score of 0.0346
# Altcoin IOTAUSDT and Altcoin MTLUSDT has a co-integration score of 0.0316
# Altcoin IOTAUSDT and Altcoin SNTUSDT has a co-integration score of 0.0033
# Altcoin IOTAUSDT and Altcoin ENGUSDT has a co-integration score of 0.0221
# Altcoin IOTAUSDT and Altcoin ZECUSDT has a co-integration score of 0.0123
# Altcoin IOTAUSDT and Altcoin DASHUSDT has a co-integration score of 0.0011
# Altcoin IOTAUSDT and Altcoin POWRUSDT has a co-integration score of 0.0211
# Altcoin IOTAUSDT and Altcoin ENJUSDT has a co-integration score of 0.0128
# Altcoin IOTAUSDT and Altcoin RDNUSDT has a co-integration score of 0.014
# Altcoin IOTAUSDT and Altcoin DLTUSDT has a co-integration score of 0.0451
# Altcoin IOTAUSDT and Altcoin AMBUSDT has a co-integration score of 0.0169
# Altcoin IOTAUSDT and Altcoin BATUSDT has a co-integration score of 0.0054
# Altcoin IOTAUSDT and Altcoin CDTUSDT has a co-integration score of 0.0039
# Altcoin IOTAUSDT and Altcoin GXSUSDT has a co-integration score of 0.0102
# Altcoin IOTAUSDT and Altcoin XZCUSDT has a co-integration score of 0.0381
# Altcoin IOTAUSDT and Altcoin BCDUSDT has a co-integration score of 0.0452
# Altcoin IOTAUSDT and Altcoin ADXUSDT has a co-integration score of 0.0404
# Altcoin LINKUSDT and Altcoin XVGUSDT has a co-integration score of 0.0205
# Altcoin LINKUSDT and Altcoin SNTUSDT has a co-integration score of 0.0005
# Altcoin LINKUSDT and Altcoin EVXUSDT has a co-integration score of 0.0162
# Altcoin LINKUSDT and Altcoin VIBUSDT has a co-integration score of 0.027
# Altcoin LINKUSDT and Altcoin XRPUSDT has a co-integration score of 0.0039
# Altcoin LINKUSDT and Altcoin KMDUSDT has a co-integration score of 0.0308
# Altcoin LINKUSDT and Altcoin RDNUSDT has a co-integration score of 0.0447
# Altcoin LINKUSDT and Altcoin GXSUSDT has a co-integration score of 0.0239
# Altcoin LINKUSDT and Altcoin POEUSDT has a co-integration score of 0.0149
# Altcoin LINKUSDT and Altcoin XZCUSDT has a co-integration score of 0.0114
# Altcoin LINKUSDT and Altcoin BCDUSDT has a co-integration score of 0.0066
# Altcoin XVGUSDT and Altcoin MDAUSDT has a co-integration score of 0.0108
# Altcoin XVGUSDT and Altcoin MTLUSDT has a co-integration score of 0.012
# Altcoin XVGUSDT and Altcoin SNTUSDT has a co-integration score of 0.0068
# Altcoin XVGUSDT and Altcoin MTHUSDT has a co-integration score of 0.0161
# Altcoin XVGUSDT and Altcoin DNTUSDT has a co-integration score of 0.0024
# Altcoin XVGUSDT and Altcoin ZECUSDT has a co-integration score of 0.0212
# Altcoin XVGUSDT and Altcoin ASTUSDT has a co-integration score of 0.0113
# Altcoin XVGUSDT and Altcoin DASHUSDT has a co-integration score of 0.033
# Altcoin XVGUSDT and Altcoin OAXUSDT has a co-integration score of 0.0097
# Altcoin XVGUSDT and Altcoin BTGUSDT has a co-integration score of 0.0385
# Altcoin XVGUSDT and Altcoin EVXUSDT has a co-integration score of 0.0313
# Altcoin XVGUSDT and Altcoin REQUSDT has a co-integration score of 0.0001
# Altcoin XVGUSDT and Altcoin VIBUSDT has a co-integration score of 0.0228
# Altcoin XVGUSDT and Altcoin POWRUSDT has a co-integration score of 0.0106
# Altcoin XVGUSDT and Altcoin ARKUSDT has a co-integration score of 0.0164
# Altcoin XVGUSDT and Altcoin XRPUSDT has a co-integration score of 0.0025
# Altcoin XVGUSDT and Altcoin STORJUSDT has a co-integration score of 0.0002
# Altcoin XVGUSDT and Altcoin RCNUSDT has a co-integration score of 0.0137
# Altcoin XVGUSDT and Altcoin RDNUSDT has a co-integration score of 0.0081
# Altcoin XVGUSDT and Altcoin XMRUSDT has a co-integration score of 0.0096
# Altcoin XVGUSDT and Altcoin DLTUSDT has a co-integration score of 0.0324
# Altcoin XVGUSDT and Altcoin AMBUSDT has a co-integration score of 0.0305
# Altcoin XVGUSDT and Altcoin BATUSDT has a co-integration score of 0.0421
# Altcoin XVGUSDT and Altcoin CDTUSDT has a co-integration score of 0.0017
# Altcoin XVGUSDT and Altcoin POEUSDT has a co-integration score of 0.0126
# Altcoin XVGUSDT and Altcoin QSPUSDT has a co-integration score of 0.0061
# Altcoin XVGUSDT and Altcoin BTSUSDT has a co-integration score of 0.002
# Altcoin XVGUSDT and Altcoin XZCUSDT has a co-integration score of 0.009
# Altcoin XVGUSDT and Altcoin TNTUSDT has a co-integration score of 0.0059
# Altcoin XVGUSDT and Altcoin FUELUSDT has a co-integration score of 0.012
# Altcoin XVGUSDT and Altcoin BCDUSDT has a co-integration score of 0.0389
# Altcoin XVGUSDT and Altcoin ADXUSDT has a co-integration score of 0.0061
# Altcoin MDAUSDT and Altcoin MTHUSDT has a co-integration score of 0.0214
# Altcoin MDAUSDT and Altcoin REQUSDT has a co-integration score of 0.0176
# Altcoin MDAUSDT and Altcoin VIBUSDT has a co-integration score of 0.0269
# Altcoin MDAUSDT and Altcoin POWRUSDT has a co-integration score of 0.0197
# Altcoin MDAUSDT and Altcoin ARKUSDT has a co-integration score of 0.0251
# Altcoin MDAUSDT and Altcoin XRPUSDT has a co-integration score of 0.0322
# Altcoin MDAUSDT and Altcoin KMDUSDT has a co-integration score of 0.0009
# Altcoin MDAUSDT and Altcoin RCNUSDT has a co-integration score of 0.0012
# Altcoin MDAUSDT and Altcoin RDNUSDT has a co-integration score of 0.0491
# Altcoin MDAUSDT and Altcoin CDTUSDT has a co-integration score of 0.0167
# Altcoin MDAUSDT and Altcoin XZCUSDT has a co-integration score of 0.0003
# Altcoin MDAUSDT and Altcoin BCDUSDT has a co-integration score of 0.0
# Altcoin MDAUSDT and Altcoin ADXUSDT has a co-integration score of 0.0025
# Altcoin MTLUSDT and Altcoin STORJUSDT has a co-integration score of 0.0336
# Altcoin MTLUSDT and Altcoin KMDUSDT has a co-integration score of 0.0217
# Altcoin MTLUSDT and Altcoin XMRUSDT has a co-integration score of 0.0472
# Altcoin MTLUSDT and Altcoin XZCUSDT has a co-integration score of 0.023
# Altcoin MTLUSDT and Altcoin ADXUSDT has a co-integration score of 0.0469
# Altcoin EOSUSDT and Altcoin TRXUSDT has a co-integration score of 0.0361
# Altcoin EOSUSDT and Altcoin MANAUSDT has a co-integration score of 0.0362
# Altcoin SNTUSDT and Altcoin ETCUSDT has a co-integration score of 0.0476
# Altcoin SNTUSDT and Altcoin MTHUSDT has a co-integration score of 0.0
# Altcoin SNTUSDT and Altcoin ENGUSDT has a co-integration score of 0.0498
# Altcoin SNTUSDT and Altcoin DNTUSDT has a co-integration score of 0.0003
# Altcoin SNTUSDT and Altcoin ZECUSDT has a co-integration score of 0.0401
# Altcoin SNTUSDT and Altcoin BNTUSDT has a co-integration score of 0.0392
# Altcoin SNTUSDT and Altcoin ASTUSDT has a co-integration score of 0.0005
# Altcoin SNTUSDT and Altcoin OAXUSDT has a co-integration score of 0.0007
# Altcoin SNTUSDT and Altcoin EVXUSDT has a co-integration score of 0.0076
# Altcoin SNTUSDT and Altcoin REQUSDT has a co-integration score of 0.0029
# Altcoin SNTUSDT and Altcoin VIBUSDT has a co-integration score of 0.0
# Altcoin SNTUSDT and Altcoin ARKUSDT has a co-integration score of 0.0011
# Altcoin SNTUSDT and Altcoin XRPUSDT has a co-integration score of 0.0212
# Altcoin SNTUSDT and Altcoin ENJUSDT has a co-integration score of 0.001
# Altcoin SNTUSDT and Altcoin KMDUSDT has a co-integration score of 0.0046
# Altcoin SNTUSDT and Altcoin RCNUSDT has a co-integration score of 0.018
# Altcoin SNTUSDT and Altcoin RDNUSDT has a co-integration score of 0.0246
# Altcoin SNTUSDT and Altcoin DLTUSDT has a co-integration score of 0.0
# Altcoin SNTUSDT and Altcoin AMBUSDT has a co-integration score of 0.0321
# Altcoin SNTUSDT and Altcoin CDTUSDT has a co-integration score of 0.0467
# Altcoin SNTUSDT and Altcoin GXSUSDT has a co-integration score of 0.0208
# Altcoin SNTUSDT and Altcoin POEUSDT has a co-integration score of 0.0
# Altcoin SNTUSDT and Altcoin QSPUSDT has a co-integration score of 0.0014
# Altcoin SNTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0018
# Altcoin SNTUSDT and Altcoin LSKUSDT has a co-integration score of 0.0044
# Altcoin SNTUSDT and Altcoin TNTUSDT has a co-integration score of 0.0001
# Altcoin SNTUSDT and Altcoin FUELUSDT has a co-integration score of 0.0
# Altcoin SNTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0108
# Altcoin SNTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0006
# Altcoin ETCUSDT and Altcoin ZECUSDT has a co-integration score of 0.0118
# Altcoin ETCUSDT and Altcoin RDNUSDT has a co-integration score of 0.0344
# Altcoin ETCUSDT and Altcoin XMRUSDT has a co-integration score of 0.0047
# Altcoin ETCUSDT and Altcoin CDTUSDT has a co-integration score of 0.0277
# Altcoin ETCUSDT and Altcoin XZCUSDT has a co-integration score of 0.0144
# Altcoin ETCUSDT and Altcoin LSKUSDT has a co-integration score of 0.0433
# Altcoin MTHUSDT and Altcoin REQUSDT has a co-integration score of 0.0
# Altcoin MTHUSDT and Altcoin VIBUSDT has a co-integration score of 0.0044
# Altcoin MTHUSDT and Altcoin POWRUSDT has a co-integration score of 0.0012
# Altcoin MTHUSDT and Altcoin ARKUSDT has a co-integration score of 0.0353
# Altcoin MTHUSDT and Altcoin XRPUSDT has a co-integration score of 0.0
# Altcoin MTHUSDT and Altcoin STORJUSDT has a co-integration score of 0.0068
# Altcoin MTHUSDT and Altcoin RCNUSDT has a co-integration score of 0.002
# Altcoin MTHUSDT and Altcoin RDNUSDT has a co-integration score of 0.0004
# Altcoin MTHUSDT and Altcoin DLTUSDT has a co-integration score of 0.005
# Altcoin MTHUSDT and Altcoin CDTUSDT has a co-integration score of 0.0021
# Altcoin MTHUSDT and Altcoin GXSUSDT has a co-integration score of 0.019
# Altcoin MTHUSDT and Altcoin POEUSDT has a co-integration score of 0.0174
# Altcoin MTHUSDT and Altcoin XZCUSDT has a co-integration score of 0.0062
# Altcoin MTHUSDT and Altcoin TNTUSDT has a co-integration score of 0.0078
# Altcoin MTHUSDT and Altcoin FUELUSDT has a co-integration score of 0.005
# Altcoin MTHUSDT and Altcoin BCDUSDT has a co-integration score of 0.0082
# Altcoin MTHUSDT and Altcoin ADXUSDT has a co-integration score of 0.0069
# Altcoin ENGUSDT and Altcoin ASTUSDT has a co-integration score of 0.0145
# Altcoin ENGUSDT and Altcoin AMBUSDT has a co-integration score of 0.0462
# Altcoin ENGUSDT and Altcoin POEUSDT has a co-integration score of 0.0044
# Altcoin ENGUSDT and Altcoin QSPUSDT has a co-integration score of 0.0368
# Altcoin ENGUSDT and Altcoin BCDUSDT has a co-integration score of 0.0297
# Altcoin DNTUSDT and Altcoin BNTUSDT has a co-integration score of 0.017
# Altcoin DNTUSDT and Altcoin ASTUSDT has a co-integration score of 0.0469
# Altcoin DNTUSDT and Altcoin REQUSDT has a co-integration score of 0.0101
# Altcoin DNTUSDT and Altcoin VIBUSDT has a co-integration score of 0.0034
# Altcoin DNTUSDT and Altcoin ARKUSDT has a co-integration score of 0.014
# Altcoin DNTUSDT and Altcoin XRPUSDT has a co-integration score of 0.0002
# Altcoin DNTUSDT and Altcoin STORJUSDT has a co-integration score of 0.0042
# Altcoin DNTUSDT and Altcoin KMDUSDT has a co-integration score of 0.0164
# Altcoin DNTUSDT and Altcoin RCNUSDT has a co-integration score of 0.0015
# Altcoin DNTUSDT and Altcoin RDNUSDT has a co-integration score of 0.0474
# Altcoin DNTUSDT and Altcoin DLTUSDT has a co-integration score of 0.041
# Altcoin DNTUSDT and Altcoin CDTUSDT has a co-integration score of 0.0455
# Altcoin DNTUSDT and Altcoin GXSUSDT has a co-integration score of 0.0383
# Altcoin DNTUSDT and Altcoin BTSUSDT has a co-integration score of 0.0418
# Altcoin DNTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0098
# Altcoin DNTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0011
# Altcoin DNTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0026
# Altcoin ZECUSDT and Altcoin DASHUSDT has a co-integration score of 0.0373
# Altcoin ZECUSDT and Altcoin BTGUSDT has a co-integration score of 0.0385
# Altcoin ZECUSDT and Altcoin REQUSDT has a co-integration score of 0.0354
# Altcoin ZECUSDT and Altcoin VIBUSDT has a co-integration score of 0.01
# Altcoin ZECUSDT and Altcoin POWRUSDT has a co-integration score of 0.0294
# Altcoin ZECUSDT and Altcoin ARKUSDT has a co-integration score of 0.0174
# Altcoin ZECUSDT and Altcoin XRPUSDT has a co-integration score of 0.0186
# Altcoin ZECUSDT and Altcoin STORJUSDT has a co-integration score of 0.0306
# Altcoin ZECUSDT and Altcoin KMDUSDT has a co-integration score of 0.003
# Altcoin ZECUSDT and Altcoin RCNUSDT has a co-integration score of 0.0002
# Altcoin ZECUSDT and Altcoin RDNUSDT has a co-integration score of 0.0015
# Altcoin ZECUSDT and Altcoin XMRUSDT has a co-integration score of 0.0417
# Altcoin ZECUSDT and Altcoin CDTUSDT has a co-integration score of 0.0006
# Altcoin ZECUSDT and Altcoin BTSUSDT has a co-integration score of 0.0494
# Altcoin ZECUSDT and Altcoin XZCUSDT has a co-integration score of 0.0
# Altcoin ZECUSDT and Altcoin TNTUSDT has a co-integration score of 0.0247
# Altcoin ZECUSDT and Altcoin FUELUSDT has a co-integration score of 0.0467
# Altcoin ZECUSDT and Altcoin BCDUSDT has a co-integration score of 0.0052
# Altcoin ZECUSDT and Altcoin ADXUSDT has a co-integration score of 0.0
# Altcoin BNTUSDT and Altcoin OAXUSDT has a co-integration score of 0.0285
# Altcoin BNTUSDT and Altcoin EVXUSDT has a co-integration score of 0.0311
# Altcoin BNTUSDT and Altcoin AMBUSDT has a co-integration score of 0.012
# Altcoin BNTUSDT and Altcoin GXSUSDT has a co-integration score of 0.006
# Altcoin BNTUSDT and Altcoin POEUSDT has a co-integration score of 0.0024
# Altcoin BNTUSDT and Altcoin QSPUSDT has a co-integration score of 0.0025
# Altcoin BNTUSDT and Altcoin XZCUSDT has a co-integration score of 0.013
# Altcoin BNTUSDT and Altcoin TNTUSDT has a co-integration score of 0.0055
# Altcoin BNTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0191
# Altcoin ASTUSDT and Altcoin EVXUSDT has a co-integration score of 0.0114
# Altcoin ASTUSDT and Altcoin REQUSDT has a co-integration score of 0.0216
# Altcoin ASTUSDT and Altcoin VIBUSDT has a co-integration score of 0.0146
# Altcoin ASTUSDT and Altcoin XRPUSDT has a co-integration score of 0.0143
# Altcoin ASTUSDT and Altcoin STORJUSDT has a co-integration score of 0.0483
# Altcoin ASTUSDT and Altcoin KMDUSDT has a co-integration score of 0.0413
# Altcoin ASTUSDT and Altcoin RCNUSDT has a co-integration score of 0.0376
# Altcoin ASTUSDT and Altcoin XMRUSDT has a co-integration score of 0.0296
# Altcoin ASTUSDT and Altcoin AMBUSDT has a co-integration score of 0.0203
# Altcoin ASTUSDT and Altcoin CDTUSDT has a co-integration score of 0.017
# Altcoin ASTUSDT and Altcoin GXSUSDT has a co-integration score of 0.0408
# Altcoin ASTUSDT and Altcoin POEUSDT has a co-integration score of 0.0
# Altcoin ASTUSDT and Altcoin QSPUSDT has a co-integration score of 0.0007
# Altcoin ASTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0167
# Altcoin ASTUSDT and Altcoin LSKUSDT has a co-integration score of 0.0452
# Altcoin ASTUSDT and Altcoin TNTUSDT has a co-integration score of 0.0007
# Altcoin ASTUSDT and Altcoin FUELUSDT has a co-integration score of 0.034
# Altcoin ASTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0015
# Altcoin ASTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0163
# Altcoin DASHUSDT and Altcoin BTGUSDT has a co-integration score of 0.0359
# Altcoin DASHUSDT and Altcoin KMDUSDT has a co-integration score of 0.0152
# Altcoin DASHUSDT and Altcoin XZCUSDT has a co-integration score of 0.0339
# Altcoin OAXUSDT and Altcoin BTGUSDT has a co-integration score of 0.0375
# Altcoin OAXUSDT and Altcoin EVXUSDT has a co-integration score of 0.0034
# Altcoin OAXUSDT and Altcoin REQUSDT has a co-integration score of 0.0062
# Altcoin OAXUSDT and Altcoin VIBUSDT has a co-integration score of 0.0182
# Altcoin OAXUSDT and Altcoin ARKUSDT has a co-integration score of 0.0174
# Altcoin OAXUSDT and Altcoin XRPUSDT has a co-integration score of 0.0022
# Altcoin OAXUSDT and Altcoin ENJUSDT has a co-integration score of 0.0014
# Altcoin OAXUSDT and Altcoin RCNUSDT has a co-integration score of 0.0178
# Altcoin OAXUSDT and Altcoin XMRUSDT has a co-integration score of 0.0057
# Altcoin OAXUSDT and Altcoin POEUSDT has a co-integration score of 0.0004
# Altcoin OAXUSDT and Altcoin QSPUSDT has a co-integration score of 0.0042
# Altcoin OAXUSDT and Altcoin XZCUSDT has a co-integration score of 0.0012
# Altcoin OAXUSDT and Altcoin LSKUSDT has a co-integration score of 0.0052
# Altcoin OAXUSDT and Altcoin TNTUSDT has a co-integration score of 0.0311
# Altcoin OAXUSDT and Altcoin FUELUSDT has a co-integration score of 0.0161
# Altcoin OAXUSDT and Altcoin BCDUSDT has a co-integration score of 0.0002
# Altcoin OAXUSDT and Altcoin ADXUSDT has a co-integration score of 0.0149
# Altcoin BTGUSDT and Altcoin REQUSDT has a co-integration score of 0.0265
# Altcoin BTGUSDT and Altcoin VIBUSDT has a co-integration score of 0.0157
# Altcoin BTGUSDT and Altcoin POWRUSDT has a co-integration score of 0.0188
# Altcoin BTGUSDT and Altcoin ARKUSDT has a co-integration score of 0.0382
# Altcoin BTGUSDT and Altcoin ENJUSDT has a co-integration score of 0.0297
# Altcoin BTGUSDT and Altcoin KMDUSDT has a co-integration score of 0.0119
# Altcoin BTGUSDT and Altcoin CDTUSDT has a co-integration score of 0.0341
# Altcoin BTGUSDT and Altcoin GXSUSDT has a co-integration score of 0.0425
# Altcoin BTGUSDT and Altcoin BTSUSDT has a co-integration score of 0.0016
# Altcoin BTGUSDT and Altcoin XZCUSDT has a co-integration score of 0.0279
# Altcoin BTGUSDT and Altcoin LSKUSDT has a co-integration score of 0.0086
# Altcoin BTGUSDT and Altcoin TNTUSDT has a co-integration score of 0.0228
# Altcoin BTGUSDT and Altcoin ADXUSDT has a co-integration score of 0.0128
# Altcoin EVXUSDT and Altcoin REQUSDT has a co-integration score of 0.002
# Altcoin EVXUSDT and Altcoin XRPUSDT has a co-integration score of 0.0232
# Altcoin EVXUSDT and Altcoin ENJUSDT has a co-integration score of 0.0273
# Altcoin EVXUSDT and Altcoin STORJUSDT has a co-integration score of 0.0269
# Altcoin EVXUSDT and Altcoin DLTUSDT has a co-integration score of 0.0052
# Altcoin EVXUSDT and Altcoin CDTUSDT has a co-integration score of 0.0435
# Altcoin EVXUSDT and Altcoin POEUSDT has a co-integration score of 0.0018
# Altcoin EVXUSDT and Altcoin QSPUSDT has a co-integration score of 0.0104
# Altcoin EVXUSDT and Altcoin XZCUSDT has a co-integration score of 0.0098
# Altcoin EVXUSDT and Altcoin LSKUSDT has a co-integration score of 0.0154
# Altcoin EVXUSDT and Altcoin TNTUSDT has a co-integration score of 0.0062
# Altcoin EVXUSDT and Altcoin FUELUSDT has a co-integration score of 0.0196
# Altcoin EVXUSDT and Altcoin BCDUSDT has a co-integration score of 0.0001
# Altcoin EVXUSDT and Altcoin ADXUSDT has a co-integration score of 0.0345
# Altcoin REQUSDT and Altcoin VIBUSDT has a co-integration score of 0.0
# Altcoin REQUSDT and Altcoin POWRUSDT has a co-integration score of 0.0036
# Altcoin REQUSDT and Altcoin ARKUSDT has a co-integration score of 0.0005
# Altcoin REQUSDT and Altcoin STORJUSDT has a co-integration score of 0.0025
# Altcoin REQUSDT and Altcoin KMDUSDT has a co-integration score of 0.0001
# Altcoin REQUSDT and Altcoin RCNUSDT has a co-integration score of 0.0002
# Altcoin REQUSDT and Altcoin RDNUSDT has a co-integration score of 0.0015
# Altcoin REQUSDT and Altcoin XMRUSDT has a co-integration score of 0.036
# Altcoin REQUSDT and Altcoin DLTUSDT has a co-integration score of 0.005
# Altcoin REQUSDT and Altcoin XZCUSDT has a co-integration score of 0.0005
# Altcoin REQUSDT and Altcoin TNTUSDT has a co-integration score of 0.0063
# Altcoin REQUSDT and Altcoin FUELUSDT has a co-integration score of 0.0333
# Altcoin REQUSDT and Altcoin BCDUSDT has a co-integration score of 0.0002
# Altcoin REQUSDT and Altcoin ADXUSDT has a co-integration score of 0.0
# Altcoin VIBUSDT and Altcoin POWRUSDT has a co-integration score of 0.0007
# Altcoin VIBUSDT and Altcoin ARKUSDT has a co-integration score of 0.0004
# Altcoin VIBUSDT and Altcoin XRPUSDT has a co-integration score of 0.0001
# Altcoin VIBUSDT and Altcoin STORJUSDT has a co-integration score of 0.0
# Altcoin VIBUSDT and Altcoin KMDUSDT has a co-integration score of 0.0028
# Altcoin VIBUSDT and Altcoin RCNUSDT has a co-integration score of 0.0001
# Altcoin VIBUSDT and Altcoin RDNUSDT has a co-integration score of 0.0036
# Altcoin VIBUSDT and Altcoin DLTUSDT has a co-integration score of 0.0097
# Altcoin VIBUSDT and Altcoin CDTUSDT has a co-integration score of 0.0
# Altcoin VIBUSDT and Altcoin GXSUSDT has a co-integration score of 0.0256
# Altcoin VIBUSDT and Altcoin POEUSDT has a co-integration score of 0.0019
# Altcoin VIBUSDT and Altcoin QSPUSDT has a co-integration score of 0.0054
# Altcoin VIBUSDT and Altcoin XZCUSDT has a co-integration score of 0.0001
# Altcoin VIBUSDT and Altcoin TNTUSDT has a co-integration score of 0.0004
# Altcoin VIBUSDT and Altcoin FUELUSDT has a co-integration score of 0.0033
# Altcoin VIBUSDT and Altcoin BCDUSDT has a co-integration score of 0.0032
# Altcoin VIBUSDT and Altcoin ADXUSDT has a co-integration score of 0.0007
# Altcoin TRXUSDT and Altcoin POWRUSDT has a co-integration score of 0.0329
# Altcoin TRXUSDT and Altcoin ARKUSDT has a co-integration score of 0.0154
# Altcoin TRXUSDT and Altcoin STORJUSDT has a co-integration score of 0.0177
# Altcoin TRXUSDT and Altcoin KMDUSDT has a co-integration score of 0.0162
# Altcoin TRXUSDT and Altcoin RCNUSDT has a co-integration score of 0.0319
# Altcoin TRXUSDT and Altcoin NULSUSDT has a co-integration score of 0.0017
# Altcoin TRXUSDT and Altcoin RDNUSDT has a co-integration score of 0.0333
# Altcoin TRXUSDT and Altcoin XMRUSDT has a co-integration score of 0.0144
# Altcoin TRXUSDT and Altcoin AMBUSDT has a co-integration score of 0.0037
# Altcoin TRXUSDT and Altcoin BATUSDT has a co-integration score of 0.0216
# Altcoin TRXUSDT and Altcoin ARNUSDT has a co-integration score of 0.0407
# Altcoin TRXUSDT and Altcoin GXSUSDT has a co-integration score of 0.0386
# Altcoin TRXUSDT and Altcoin XZCUSDT has a co-integration score of 0.0077
# Altcoin TRXUSDT and Altcoin LSKUSDT has a co-integration score of 0.0247
# Altcoin TRXUSDT and Altcoin TNTUSDT has a co-integration score of 0.0456
# Altcoin TRXUSDT and Altcoin MANAUSDT has a co-integration score of 0.0002
# Altcoin TRXUSDT and Altcoin BCDUSDT has a co-integration score of 0.0106
# Altcoin TRXUSDT and Altcoin ADXUSDT has a co-integration score of 0.0095
# Altcoin POWRUSDT and Altcoin ARKUSDT has a co-integration score of 0.0064
# Altcoin POWRUSDT and Altcoin XRPUSDT has a co-integration score of 0.0317
# Altcoin POWRUSDT and Altcoin KMDUSDT has a co-integration score of 0.0011
# Altcoin POWRUSDT and Altcoin RCNUSDT has a co-integration score of 0.0
# Altcoin POWRUSDT and Altcoin RDNUSDT has a co-integration score of 0.0026
# Altcoin POWRUSDT and Altcoin CDTUSDT has a co-integration score of 0.0018
# Altcoin POWRUSDT and Altcoin XZCUSDT has a co-integration score of 0.0
# Altcoin POWRUSDT and Altcoin TNTUSDT has a co-integration score of 0.0439
# Altcoin POWRUSDT and Altcoin BCDUSDT has a co-integration score of 0.0001
# Altcoin POWRUSDT and Altcoin ADXUSDT has a co-integration score of 0.0
# Altcoin ARKUSDT and Altcoin XRPUSDT has a co-integration score of 0.0387
# Altcoin ARKUSDT and Altcoin STORJUSDT has a co-integration score of 0.0116
# Altcoin ARKUSDT and Altcoin KMDUSDT has a co-integration score of 0.0007
# Altcoin ARKUSDT and Altcoin RCNUSDT has a co-integration score of 0.0113
# Altcoin ARKUSDT and Altcoin RDNUSDT has a co-integration score of 0.0061
# Altcoin ARKUSDT and Altcoin CDTUSDT has a co-integration score of 0.0
# Altcoin ARKUSDT and Altcoin XZCUSDT has a co-integration score of 0.0004
# Altcoin ARKUSDT and Altcoin TNTUSDT has a co-integration score of 0.0219
# Altcoin ARKUSDT and Altcoin BCDUSDT has a co-integration score of 0.0133
# Altcoin ARKUSDT and Altcoin ADXUSDT has a co-integration score of 0.0009
# Altcoin XRPUSDT and Altcoin ENJUSDT has a co-integration score of 0.0414
# Altcoin XRPUSDT and Altcoin STORJUSDT has a co-integration score of 0.017
# Altcoin XRPUSDT and Altcoin KMDUSDT has a co-integration score of 0.0006
# Altcoin XRPUSDT and Altcoin RCNUSDT has a co-integration score of 0.0125
# Altcoin XRPUSDT and Altcoin RDNUSDT has a co-integration score of 0.0082
# Altcoin XRPUSDT and Altcoin XMRUSDT has a co-integration score of 0.0048
# Altcoin XRPUSDT and Altcoin DLTUSDT has a co-integration score of 0.0021
# Altcoin XRPUSDT and Altcoin AMBUSDT has a co-integration score of 0.0455
# Altcoin XRPUSDT and Altcoin CDTUSDT has a co-integration score of 0.0059
# Altcoin XRPUSDT and Altcoin GXSUSDT has a co-integration score of 0.0003
# Altcoin XRPUSDT and Altcoin POEUSDT has a co-integration score of 0.0133
# Altcoin XRPUSDT and Altcoin XZCUSDT has a co-integration score of 0.0017
# Altcoin XRPUSDT and Altcoin LSKUSDT has a co-integration score of 0.0286
# Altcoin XRPUSDT and Altcoin TNTUSDT has a co-integration score of 0.0365
# Altcoin XRPUSDT and Altcoin FUELUSDT has a co-integration score of 0.008
# Altcoin XRPUSDT and Altcoin BCDUSDT has a co-integration score of 0.0025
# Altcoin XRPUSDT and Altcoin ADXUSDT has a co-integration score of 0.0005
# Altcoin ENJUSDT and Altcoin STORJUSDT has a co-integration score of 0.0425
# Altcoin ENJUSDT and Altcoin RCNUSDT has a co-integration score of 0.0281
# Altcoin ENJUSDT and Altcoin RDNUSDT has a co-integration score of 0.0348
# Altcoin ENJUSDT and Altcoin XMRUSDT has a co-integration score of 0.0115
# Altcoin ENJUSDT and Altcoin DLTUSDT has a co-integration score of 0.0464
# Altcoin ENJUSDT and Altcoin ARNUSDT has a co-integration score of 0.0406
# Altcoin ENJUSDT and Altcoin GXSUSDT has a co-integration score of 0.0175
# Altcoin ENJUSDT and Altcoin POEUSDT has a co-integration score of 0.0024
# Altcoin ENJUSDT and Altcoin QSPUSDT has a co-integration score of 0.0017
# Altcoin ENJUSDT and Altcoin XZCUSDT has a co-integration score of 0.0087
# Altcoin ENJUSDT and Altcoin LSKUSDT has a co-integration score of 0.0484
# Altcoin ENJUSDT and Altcoin TNTUSDT has a co-integration score of 0.0221
# Altcoin ENJUSDT and Altcoin FUELUSDT has a co-integration score of 0.0252
# Altcoin ENJUSDT and Altcoin BCDUSDT has a co-integration score of 0.0009
# Altcoin ENJUSDT and Altcoin ADXUSDT has a co-integration score of 0.019
# Altcoin STORJUSDT and Altcoin KMDUSDT has a co-integration score of 0.0005
# Altcoin STORJUSDT and Altcoin RCNUSDT has a co-integration score of 0.0141
# Altcoin STORJUSDT and Altcoin XMRUSDT has a co-integration score of 0.0445
# Altcoin STORJUSDT and Altcoin XZCUSDT has a co-integration score of 0.0029
# Altcoin STORJUSDT and Altcoin TNTUSDT has a co-integration score of 0.0439
# Altcoin STORJUSDT and Altcoin BCDUSDT has a co-integration score of 0.0092
# Altcoin STORJUSDT and Altcoin ADXUSDT has a co-integration score of 0.0035
# Altcoin KMDUSDT and Altcoin RCNUSDT has a co-integration score of 0.0002
# Altcoin KMDUSDT and Altcoin RDNUSDT has a co-integration score of 0.0063
# Altcoin KMDUSDT and Altcoin XMRUSDT has a co-integration score of 0.0253
# Altcoin KMDUSDT and Altcoin CDTUSDT has a co-integration score of 0.0131
# Altcoin KMDUSDT and Altcoin POEUSDT has a co-integration score of 0.0111
# Altcoin KMDUSDT and Altcoin BTSUSDT has a co-integration score of 0.0053
# Altcoin KMDUSDT and Altcoin XZCUSDT has a co-integration score of 0.0001
# Altcoin KMDUSDT and Altcoin TNTUSDT has a co-integration score of 0.0288
# Altcoin KMDUSDT and Altcoin BCDUSDT has a co-integration score of 0.0189
# Altcoin KMDUSDT and Altcoin ADXUSDT has a co-integration score of 0.0012
# Altcoin RCNUSDT and Altcoin RDNUSDT has a co-integration score of 0.0128
# Altcoin RCNUSDT and Altcoin CDTUSDT has a co-integration score of 0.0003
# Altcoin RCNUSDT and Altcoin GXSUSDT has a co-integration score of 0.0045
# Altcoin RCNUSDT and Altcoin POEUSDT has a co-integration score of 0.0464
# Altcoin RCNUSDT and Altcoin XZCUSDT has a co-integration score of 0.0137
# Altcoin RCNUSDT and Altcoin TNTUSDT has a co-integration score of 0.0075
# Altcoin RCNUSDT and Altcoin BCDUSDT has a co-integration score of 0.0154
# Altcoin RCNUSDT and Altcoin ADXUSDT has a co-integration score of 0.029
# Altcoin RDNUSDT and Altcoin XMRUSDT has a co-integration score of 0.0496
# Altcoin RDNUSDT and Altcoin CDTUSDT has a co-integration score of 0.0
# Altcoin RDNUSDT and Altcoin GXSUSDT has a co-integration score of 0.0417
# Altcoin RDNUSDT and Altcoin XZCUSDT has a co-integration score of 0.0004
# Altcoin RDNUSDT and Altcoin LSKUSDT has a co-integration score of 0.0457
# Altcoin RDNUSDT and Altcoin FUELUSDT has a co-integration score of 0.0412
# Altcoin RDNUSDT and Altcoin BCDUSDT has a co-integration score of 0.0016
# Altcoin RDNUSDT and Altcoin ADXUSDT has a co-integration score of 0.0
# Altcoin XMRUSDT and Altcoin CDTUSDT has a co-integration score of 0.0222
# Altcoin XMRUSDT and Altcoin POEUSDT has a co-integration score of 0.0279
# Altcoin XMRUSDT and Altcoin XZCUSDT has a co-integration score of 0.0041
# Altcoin XMRUSDT and Altcoin LSKUSDT has a co-integration score of 0.0386
# Altcoin XMRUSDT and Altcoin BCDUSDT has a co-integration score of 0.0141
# Altcoin XMRUSDT and Altcoin ADXUSDT has a co-integration score of 0.0134
# Altcoin DLTUSDT and Altcoin CDTUSDT has a co-integration score of 0.0151
# Altcoin DLTUSDT and Altcoin POEUSDT has a co-integration score of 0.0058
# Altcoin DLTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0062
# Altcoin DLTUSDT and Altcoin TNTUSDT has a co-integration score of 0.0195
# Altcoin DLTUSDT and Altcoin FUELUSDT has a co-integration score of 0.0134
# Altcoin DLTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0017
# Altcoin DLTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0073
# Altcoin AMBUSDT and Altcoin GXSUSDT has a co-integration score of 0.0168
# Altcoin AMBUSDT and Altcoin POEUSDT has a co-integration score of 0.0163
# Altcoin AMBUSDT and Altcoin QSPUSDT has a co-integration score of 0.0162
# Altcoin AMBUSDT and Altcoin XZCUSDT has a co-integration score of 0.0383
# Altcoin AMBUSDT and Altcoin LSKUSDT has a co-integration score of 0.0074
# Altcoin AMBUSDT and Altcoin BCDUSDT has a co-integration score of 0.0028
# Altcoin BATUSDT and Altcoin POEUSDT has a co-integration score of 0.0175
# Altcoin BATUSDT and Altcoin XZCUSDT has a co-integration score of 0.0151
# Altcoin BATUSDT and Altcoin MANAUSDT has a co-integration score of 0.0135
# Altcoin BATUSDT and Altcoin BCDUSDT has a co-integration score of 0.0254
# Altcoin BATUSDT and Altcoin ADXUSDT has a co-integration score of 0.0315
# Altcoin BCPTUSDT and Altcoin GXSUSDT has a co-integration score of 0.0398
# Altcoin BCPTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0344
# Altcoin BCPTUSDT and Altcoin LSKUSDT has a co-integration score of 0.0025
# Altcoin BCPTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0199
# Altcoin ARNUSDT and Altcoin POEUSDT has a co-integration score of 0.0223
# Altcoin ARNUSDT and Altcoin QSPUSDT has a co-integration score of 0.0292
# Altcoin ARNUSDT and Altcoin XZCUSDT has a co-integration score of 0.0251
# Altcoin ARNUSDT and Altcoin LSKUSDT has a co-integration score of 0.0318
# Altcoin ARNUSDT and Altcoin FUELUSDT has a co-integration score of 0.0018
# Altcoin ARNUSDT and Altcoin BCDUSDT has a co-integration score of 0.0003
# Altcoin GVTUSDT and Altcoin DGDUSDT has a co-integration score of 0.0032
# Altcoin CDTUSDT and Altcoin GXSUSDT has a co-integration score of 0.0006
# Altcoin CDTUSDT and Altcoin XZCUSDT has a co-integration score of 0.0001
# Altcoin CDTUSDT and Altcoin LSKUSDT has a co-integration score of 0.0051
# Altcoin CDTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0
# Altcoin CDTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0
# Altcoin GXSUSDT and Altcoin POEUSDT has a co-integration score of 0.0232
# Altcoin GXSUSDT and Altcoin QSPUSDT has a co-integration score of 0.036
# Altcoin GXSUSDT and Altcoin XZCUSDT has a co-integration score of 0.0003
# Altcoin GXSUSDT and Altcoin TNTUSDT has a co-integration score of 0.0095
# Altcoin GXSUSDT and Altcoin FUELUSDT has a co-integration score of 0.0145
# Altcoin GXSUSDT and Altcoin BCDUSDT has a co-integration score of 0.0009
# Altcoin GXSUSDT and Altcoin ADXUSDT has a co-integration score of 0.0012
# Altcoin POEUSDT and Altcoin QSPUSDT has a co-integration score of 0.0206
# Altcoin POEUSDT and Altcoin XZCUSDT has a co-integration score of 0.0004
# Altcoin POEUSDT and Altcoin LSKUSDT has a co-integration score of 0.0003
# Altcoin POEUSDT and Altcoin TNTUSDT has a co-integration score of 0.0349
# Altcoin POEUSDT and Altcoin FUELUSDT has a co-integration score of 0.0007
# Altcoin POEUSDT and Altcoin BCDUSDT has a co-integration score of 0.0001
# Altcoin POEUSDT and Altcoin ADXUSDT has a co-integration score of 0.0006
# Altcoin QSPUSDT and Altcoin XZCUSDT has a co-integration score of 0.0232
# Altcoin QSPUSDT and Altcoin LSKUSDT has a co-integration score of 0.0418
# Altcoin QSPUSDT and Altcoin BCDUSDT has a co-integration score of 0.0174
# Altcoin QSPUSDT and Altcoin ADXUSDT has a co-integration score of 0.0449
# Altcoin BTSUSDT and Altcoin BCDUSDT has a co-integration score of 0.0044
# Altcoin BTSUSDT and Altcoin ADXUSDT has a co-integration score of 0.0143
# Altcoin XZCUSDT and Altcoin TNTUSDT has a co-integration score of 0.0216
# Altcoin XZCUSDT and Altcoin FUELUSDT has a co-integration score of 0.0066
# Altcoin XZCUSDT and Altcoin BCDUSDT has a co-integration score of 0.0473
# Altcoin XZCUSDT and Altcoin ADXUSDT has a co-integration score of 0.0003
# Altcoin LSKUSDT and Altcoin FUELUSDT has a co-integration score of 0.0426
# Altcoin LSKUSDT and Altcoin BCDUSDT has a co-integration score of 0.0117
# Altcoin TNTUSDT and Altcoin BCDUSDT has a co-integration score of 0.0004
# Altcoin TNTUSDT and Altcoin ADXUSDT has a co-integration score of 0.0075
# Altcoin FUELUSDT and Altcoin BCDUSDT has a co-integration score of 0.0078
# Altcoin FUELUSDT and Altcoin ADXUSDT has a co-integration score of 0.0022
# Altcoin MANAUSDT and Altcoin BCDUSDT has a co-integration score of 0.0073
# Altcoin MANAUSDT and Altcoin DGDUSDT has a co-integration score of 0.0285
# Altcoin MANAUSDT and Altcoin ADXUSDT has a co-integration score of 0.0092
# Altcoin BCDUSDT and Altcoin ADXUSDT has a co-integration score of 0.007

# %% [markdown]
# We will now use the “pykalman” module to set up a couple of functions that will allow us to generate Kalman filters which we will apply to our data and in turn our regression that is fed the said data.

# %%
def KalmanFilterAverage(x):
  # Construct a Kalman filter
    kf = KalmanFilter(transition_matrices = [1],
    observation_matrices = [1],
    initial_state_mean = 0,
    initial_state_covariance = 1,
    observation_covariance=1,
    transition_covariance=.01)
  # Use the observed values of the price to get a rolling mean
    state_means, _ = kf.filter(x.values)
    state_means = pd.Series(state_means.flatten(), index=x.index)
    return state_means

# Kalman filter regression
def KalmanFilterRegression(x,y):
    delta = 1e-3
    trans_cov = delta / (1 - delta) * np.eye(2) # How much random walk wiggles
    obs_mat = np.expand_dims(np.vstack([[x], [np.ones(len(x))]]).T, axis=1)
    kf = KalmanFilter(n_dim_obs=1, n_dim_state=2, # y is 1-dimensional, (alpha, beta) is 2-dimensional
    initial_state_mean=[0,0],
    initial_state_covariance=np.ones((2, 2)),
    transition_matrices=np.eye(2),
    observation_matrices=obs_mat,
    observation_covariance=2,
    transition_covariance=trans_cov)
    # Use the observations y to get running estimates and errors for the state parameters
    state_means, state_covs = kf.filter(y.values)
    return state_means

def half_life(spread):
    spread_lag = spread.shift(1)
    spread_lag.iloc[0] = spread_lag.iloc[1]
    spread_ret = spread - spread_lag
    spread_ret.iloc[0] = spread_ret.iloc[1]
    spread_lag2 = sm.add_constant(spread_lag)
    model = sm.OLS(spread_ret,spread_lag2)
    res = model.fit()
    halflife = int(round(-np.log(2) / res.params[1],0))
    if halflife <= 0:
        halflife = 1
    return halflife

# %% [markdown]
# Now let us define our main “Backtest” function that we will run our data through. The fucntion takes one pair of tickers at a time, and then returns several outputs, namely the DataFrame of cumulative returns,
# the Sharpe Ratio and the Compound Annual Growth Rate (CAGR). Once we have defined our function, we can iterate over our list of pairs and feed the relevant data, pair by pair, into the function, storing the outputs for each pair for
# later use and retrieval.

# %%
def backtest(df,s1, s2):
    #############################################################
    # INPUT:
    # DataFrame of prices
    # s1: the symbol of contract one
    # s2: the symbol of contract two
    # x: the price series of contract one
    # y: the price series of contract two
    # OUTPUT:
    # df1['cum rets']: cumulative returns in pandas data frame
    # sharpe: Sharpe ratio
    # CAGR: Compound Annual Growth Rate
    x = df[s1]
    y = df[s2]
    
    # run regression (including Kalman Filter) to find hedge ratio and then create spread series
    df1 = pd.DataFrame({'y':y,'x':x})
    df1.index = pd.to_datetime(df1.index)
    state_means = KalmanFilterRegression(KalmanFilterAverage(x),KalmanFilterAverage(y))
    df1['hr'] = - state_means[:,0]
    df1['spread'] = df1.y + (df1.x * df1.hr)
    
    # calculate half life
    halflife = half_life(df1['spread'])
    
    # calculate z-score with window = half life period
    meanSpread = df1.spread.rolling(window=halflife).mean()
    stdSpread = df1.spread.rolling(window=halflife).std()
    df1['zScore'] = (df1.spread-meanSpread)/stdSpread
    
    ##############################################################
    
    # trading logic
    entryZscore = 1.25
    exitZscore = 0
    
    #set up num units long
    df1['long entry'] = ((df1.zScore < - entryZscore) & ( df1.zScore.shift(1) > - entryZscore))
    df1['long exit'] = ((df1.zScore > - exitZscore) & (df1.zScore.shift(1) < - exitZscore))
    df1['num units long'] = np.nan 
    df1.loc[df1['long entry'],'num units long'] = 1 
    df1.loc[df1['long exit'],'num units long'] = 0 
    df1['num units long'][0] = 0 
    df1['num units long'] = df1['num units long'].fillna(method='pad')
    
    #set up num units short 
    df1['short entry'] = ((df1.zScore > entryZscore) & ( df1.zScore.shift(1) < entryZscore))
    df1['short exit'] = ((df1.zScore < exitZscore) & (df1.zScore.shift(1) > exitZscore))
    df1.loc[df1['short entry'],'num units short'] = -1
    df1.loc[df1['short exit'],'num units short'] = 0
    df1['num units short'][0] = 0
    df1['num units short'] = df1['num units short'].fillna(method='pad')
    df1['numUnits'] = df1['num units long'] + df1['num units short']
    df1['spread pct ch'] = (df1['spread'] - df1['spread'].shift(1)) / ((df1['x'] * abs(df1['hr'])) + df1['y'])
    df1['port rets'] = df1['spread pct ch'] * df1['numUnits'].shift(1)
    df1['cum rets'] = df1['port rets'].cumsum()
    df1['cum rets'] = df1['cum rets'] + 1

    ##############################################################
    
    try:
        sharpe = ((df1['port rets'].mean() / df1['port rets'].std()) * sqrt(252))
    except ZeroDivisionError:
        sharpe = 0.0
        
    ##############################################################
    
    start_val = 1
    end_val = df1['cum rets'].iat[-1]
    start_date = df1.iloc[0].name
    end_date = df1.iloc[-1].name
    days = (end_date - start_date).days
    CAGR = (end_val / start_val) ** (252.0/days) - 1
    #CAGR = round(((float(end_val) / float(start_val)) ** (252.0/days)) - 1,4)
    df1[s1+ " "+s2] = df1['cum rets']
    return df1[s1+" "+s2], sharpe, CAGR

# %% [markdown]
# So now let’s run our full list of pairs through our Backtest function, and print out some results along the way, and finally after storing the equity curve for each pair,
# produce a chart that plots out each curve.

# %%
results = []
for pair in pairs:
    rets, sharpe,  CAGR = backtest(df[split:],pair[0],pair[1])
    rets2, sharpe2,  CAGR2 = backtest(df[:split],pair[0],pair[1])
    if round(sharpe2,2) > 1.49:
        results.append(rets)
        print("The pair {} and {} produced a Sharpe Ratio of {} and a CAGR of {}".format(pair[0],pair[1],round(sharpe,2),round(CAGR,4)))
        #print("The pair {} and {} produced a Sharpe Ratio of {} and a CAGR of {}".format(pair[0],pair[1],round(sharpe,2),round(CAGR,4)))
        rets.plot(figsize=(12,6),legend=True)
        plt.legend(bbox_to_anchor=(1.01, 1.1), loc='upper left', ncol=1)
        plt.grid(b=None, which=u'major', axis=u'both')
        plt.title('> 1.49 Sharpe Binance USDT Denominated Altcoin Pairs Returns')
        plt.xlabel('Date')
        plt.ylabel('Pair Returns');
# Out:
# The pair ETHUSDT and WTCUSDT produced a Sharpe Ratio of 1.4 and a CAGR of 0.6687
# The pair ETHUSDT and OAXUSDT produced a Sharpe Ratio of 0.0 and a CAGR of 0.0
# The pair ETHUSDT and CDTUSDT produced a Sharpe Ratio of 1.83 and a CAGR of 1.0438
# The pair ETHUSDT and XZCUSDT produced a Sharpe Ratio of 1.52 and a CAGR of 0.6497
# The pair ETHUSDT and FUELUSDT produced a Sharpe Ratio of 2.66 and a CAGR of 1.3174
# The pair ETHUSDT and ADXUSDT produced a Sharpe Ratio of 0.0 and a CAGR of 0.0
# The pair LTCUSDT and OAXUSDT produced a Sharpe Ratio of 1.34 and a CAGR of 1.0304
# The pair NEOUSDT and OAXUSDT produced a Sharpe Ratio of 0.61 and a CAGR of 0.6197
# The pair GASUSDT and KNCUSDT produced a Sharpe Ratio of 0.8 and a CAGR of 0.5687
# The pair GASUSDT and OAXUSDT produced a Sharpe Ratio of 0.86 and a CAGR of 0.9026
# The pair GASUSDT and EVXUSDT produced a Sharpe Ratio of 1.03 and a CAGR of 1.0372
# The pair GASUSDT and AMBUSDT produced a Sharpe Ratio of 0.99 and a CAGR of 0.6606
# The pair GASUSDT and QSPUSDT produced a Sharpe Ratio of 1.34 and a CAGR of 0.8157
# The pair QTUMUSDT and OAXUSDT produced a Sharpe Ratio of 0.37 and a CAGR of 0.444
# The pair STRATUSDT and REQUSDT produced a Sharpe Ratio of 1.05 and a CAGR of 0.7329
# The pair MDAUSDT and BCDUSDT produced a Sharpe Ratio of 0.14 and a CAGR of 0.2994
# The pair MDAUSDT and ADXUSDT produced a Sharpe Ratio of 0.98 and a CAGR of 0.9467
# The pair MTLUSDT and ADXUSDT produced a Sharpe Ratio of 1.22 and a CAGR of 1.0419
# The pair ETCUSDT and RDNUSDT produced a Sharpe Ratio of 0.16 and a CAGR of 0.1217
# The pair ETCUSDT and XZCUSDT produced a Sharpe Ratio of 0.94 and a CAGR of 0.6047
# The pair ZECUSDT and DASHUSDT produced a Sharpe Ratio of 1.96 and a CAGR of 0.593
# The pair ZECUSDT and BTGUSDT produced a Sharpe Ratio of 1.84 and a CAGR of 0.7351
# The pair ZECUSDT and VIBUSDT produced a Sharpe Ratio of 1.25 and a CAGR of 0.652
# The pair ZECUSDT and RDNUSDT produced a Sharpe Ratio of 1.11 and a CAGR of 0.6566
# The pair ZECUSDT and CDTUSDT produced a Sharpe Ratio of 1.47 and a CAGR of 0.8804
# The pair ZECUSDT and XZCUSDT produced a Sharpe Ratio of 0.0 and a CAGR of 0.0
# The pair ZECUSDT and TNTUSDT produced a Sharpe Ratio of 1.13 and a CAGR of 0.8563
# The pair ZECUSDT and FUELUSDT produced a Sharpe Ratio of 1.52 and a CAGR of 0.9479
# The pair ZECUSDT and ADXUSDT produced a Sharpe Ratio of 0.0 and a CAGR of 0.0
# The pair DASHUSDT and XZCUSDT produced a Sharpe Ratio of 1.99 and a CAGR of 0.9987
# The pair BTGUSDT and REQUSDT produced a Sharpe Ratio of 1.96 and a CAGR of 1.1064
# The pair BTGUSDT and VIBUSDT produced a Sharpe Ratio of 1.3 and a CAGR of 0.8154
# The pair BTGUSDT and CDTUSDT produced a Sharpe Ratio of 1.35 and a CAGR of 0.9611
# The pair BTGUSDT and BTSUSDT produced a Sharpe Ratio of 1.3 and a CAGR of 0.5729
# The pair BTGUSDT and XZCUSDT produced a Sharpe Ratio of 0.93 and a CAGR of 0.5988
# The pair BTGUSDT and TNTUSDT produced a Sharpe Ratio of 1.36 and a CAGR of 1.1149
# The pair BTGUSDT and ADXUSDT produced a Sharpe Ratio of 1.21 and a CAGR of 0.813
# The pair EVXUSDT and DLTUSDT produced a Sharpe Ratio of 0.27 and a CAGR of 0.4014
# The pair EVXUSDT and FUELUSDT produced a Sharpe Ratio of 0.13 and a CAGR of 0.1797
# The pair EVXUSDT and ADXUSDT produced a Sharpe Ratio of 1.01 and a CAGR of 0.8883
# The pair ARKUSDT and STORJUSDT produced a Sharpe Ratio of 0.49 and a CAGR of 0.4256
# The pair ARKUSDT and RCNUSDT produced a Sharpe Ratio of 0.5 and a CAGR of 0.5596
# The pair ARKUSDT and XZCUSDT produced a Sharpe Ratio of 0.8 and a CAGR of 0.6032
# The pair RDNUSDT and FUELUSDT produced a Sharpe Ratio of -0.2 and a CAGR of -0.2732
# The pair RDNUSDT and ADXUSDT produced a Sharpe Ratio of 1.57 and a CAGR of 1.2514
# The pair XMRUSDT and CDTUSDT produced a Sharpe Ratio of 2.1 and a CAGR of 1.2072
# The pair XMRUSDT and XZCUSDT produced a Sharpe Ratio of 2.03 and a CAGR of 0.8556
# The pair XMRUSDT and LSKUSDT produced a Sharpe Ratio of 2.32 and a CAGR of 0.8059
# The pair XMRUSDT and ADXUSDT produced a Sharpe Ratio of 0.0 and a CAGR of 0.0
# The pair XZCUSDT and TNTUSDT produced a Sharpe Ratio of 1.17 and a CAGR of 0.9997
# The pair XZCUSDT and FUELUSDT produced a Sharpe Ratio of 1.25 and a CAGR of 0.9244
# The pair XZCUSDT and BCDUSDT produced a Sharpe Ratio of 0.34 and a CAGR of 0.4795

# %% [markdown]
# Now we run a few extra lines of code to combine, equally weight, and print our our final equity curve:

# %%
#concatenate together the individual equity curves into a single DataFrame
results_df = pd.concat(results,axis=1).dropna()

#equally weight each equity curve by dividing each by the number of pairs held in the DataFrame
results_df /= len(results_df.columns)

#sum up the equally weighted equity curves to get our final equity curve
final_res = results_df.sum(axis=1)

#plot the chart of our final equity curve
final_res.plot(label='Portfolio Value ($)',color='#50db14', figsize=(12,6))
plt.title('> 1.49 Sharpe Equallly Weighted Binance USDT Denominated Altcoin Pairs Trade Returns')
plt.margins(0.001)
plt.grid(b=None, which=u'major', axis=u'both')
plt.xlabel('Date')
plt.ylabel('Portfolio Value ($)')
plt.legend();

# %% [markdown]
# ### Underwater Plot

# %%
ffn.to_drawdown_series(final_res).plot(kind = 'area',alpha=.4,label='Drawdown',color='#ff3838',figsize=(12,6),grid=False)
plt.title('> 1.49 Sharpe Equallly Weighted Binance USDT Denominated Altcoin Pairs Trade Drawdowns')
plt.margins(0.001)
plt.xlabel('Date')
plt.ylabel('Drawdown (%)')
plt.legend(loc='lower right');

# %%
num_coins = len(results_df.columns)
print('Number of Pairs =', num_coins)
# Out:
# Number of Pairs = 52

# %% [markdown]
# ### Total Returns Performance

# %%
perf = final_res.calc_stats()
perf.display()
# Out:
# Stats for None from 2018-08-25 16:00:00 - 2019-09-30 16:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR     Max Drawdown
# --------------  --------  -------  --------------
# 132.48%             5.93  115.64%  -5.02%
#
# Annualized Returns:
# mtd    3m      6m      ytd     1y       3y       5y    10y    incep.
# -----  ------  ------  ------  -------  -------  ----  -----  --------
# 3.74%  15.64%  37.46%  69.32%  103.22%  115.64%  -     -      115.64%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  5.93     5.50       -
# mean    53.47%   80.35%     69.32%
# vol     9.02%    14.60%     -
# skew    3.47     -0.43      -
# kurt    37.92    1.65       -
# best    6.43%    13.58%     69.32%
# worst   -2.01%   -2.92%     69.32%
#
# Drawdowns:
# max     avg       # days
# ------  ------  --------
# -5.02%  -0.46%      2.39
#
# Misc:
# ---------------  -------
# avg. up month    7.50%
# avg. down month  -2.92%
# up year %        100.00%
# 12m up %         100.00%
# ---------------  -------

# %% [markdown]
# ### Monthly Returns Performance

# %%
perf.display_monthly_returns()
# Out:
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec    YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
#   2018   0      0      0      0      0      0      0      1.06  13.2    8.85  -2.92  13.58  37.31
#   2019   5.96   7.38   8.14   3.86   8.22   5.86   4.84   6.32   3.74   0      0      0     69.32

# %%
perf.stats
# Out:
# start                    2018-08-25 16:00:00
# end                      2019-09-30 16:00:00
# rf                                         0
# total_return                         1.32483
# cagr                                 1.15639
# max_drawdown                      -0.0502356
# calmar                               23.0192
# mtd                                0.0374225
# three_month                         0.156442
# six_month                            0.37459
# ytd                                 0.693185
# one_year                              1.0322
# three_year                           1.15639
# five_year                                NaN
# ten_year                                 NaN
# incep                                1.15639
# daily_sharpe                         5.92648
# daily_sortino                        14.5353
# daily_mean                          0.534731
# daily_vol                          0.0902275
# daily_skew                           3.46647
# daily_kurt                           37.9245
# best_day                             0.06427
# worst_day                         -0.0201488
# monthly_sharpe                       5.50395
# monthly_sortino                      28.6797
# monthly_mean                        0.803533
# monthly_vol                         0.145992
# monthly_skew                       -0.429461
# monthly_kurt                         1.64601
# best_month                          0.135752
# worst_month                       -0.0291615
# yearly_sharpe                            NaN
# yearly_sortino                           NaN
# yearly_mean                         0.693185
# yearly_vol                               NaN
# yearly_skew                              NaN
# yearly_kurt                              NaN
# best_year                           0.693185
# worst_year                          0.693185
# avg_drawdown                     -0.00457003
# avg_drawdown_days                    2.39062
# avg_up_month                       0.0749713
# avg_down_month                    -0.0291615
# win_year_perc                              1
# twelve_month_win_perc                      1
# dtype: object

# %% [markdown]
# The Sharpe Ratio is very good. Also take into consideration trading cost for crypto currency is very minimal but was not factored in these performance stats. The testing period was only from August 2018 until September 29th 2019 only looking at specific pairs returns when traded in the training period that was able to yield a greater than 1.49 sharpe ratio on 8hr closing prices. Then creating an equal weight portfolio of those high yielding sharpe pairs to trade in the test period. Cummulative returns were almost 82% for about 1yr with decent drawdown (fucking impressive).
